# %% [markdown]
# # 7. PyTorch Basics - Good practices in Deep Learning Projects
#
# ### About this notebook
#
# This notebook was used in the 50.039 Deep Learning course at the Singapore University of Technology and Design.
#
# **Author:** Matthieu DE MARI (matthieu_demari@sutd.edu.sg)
#
# **Version:** 1.1 (03/02/2022)
#
# **Requirements:**
# - Python 3 (tested on v3.9.6)
# - Matplotlib (tested on v3.5.1)
# - Numpy (tested on v1.22.1)
# - Torch (tested on v1.13.0)
# - Torchmetrics (tested on v0.11.0)

# %% [markdown]
# ### Imports and CUDA

# %%
# Matplotlib
import matplotlib.pyplot as plt
# Numpy
import numpy as np
# Torch
import torch
import torchvision
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Compose, Normalize
from torchvision.datasets import MNIST

# %%
# Use GPU if available, else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### The MNIST Dataset
#
# As in the previous notebook

# %%
# Define transform to convert images to tensors and normalize them
transform_data = Compose([ToTensor(),
                          Normalize((0.1307,), (0.3081,))])

# Load the data
batch_size = 256
train_dataset = MNIST(root='./mnist/', train = True, download = True, transform = transform_data)
test_dataset = MNIST(root='./mnist/', train = False, download = True, transform = transform_data)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)

# %% [markdown]
# ### Our deep neural network
#
# As in the previous notebook.
#
# However, we have stremalined the DeepNeuralNet class and its init method so that it can work with any number of elements in the list n_h (instead of just 3). The Sequential will then adjust automatically to produce any appropriate number of DenseReLU layers and finish with a single DenseSoftmax one.

# %%
class DenseReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        # Using ReLU operation as activation after
        return torch.relu(self.fc(x))

# %%
class DenseNoReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        return self.fc(x)

# %%
class DeepNeuralNet(torch.nn.Module):
    def __init__(self, n_x, n_h, n_y):
        super().__init__()
        # Define the correct number of Dense + ReLU layers based on n_h,
        # followed by one final Dense + Softmax layer
        values = [n_x] + n_h
        self.processing_layers = [DenseReLU(values[i], values[i + 1]) for i in range(len(values) - 1)]
        self.processing_layers += [DenseNoReLU(n_h[-1], n_y)]
        
        # Combine all layers
        # Important: note the * symbol before the list of layers in self.processing_layers
        # Not sure what it does? Check the *args and **kwargs concepts in Python.
        self.combined_layers = torch.nn.Sequential(*self.processing_layers)

    
    def forward(self, x):
        # Flatten images (transform them from 28x28 2D matrices to 784 1D vectors)
        x = x.view(x.size(0), -1)
        # Pass through all four layers
        out = self.combined_layers(x)
        return out

# %% [markdown]
# Let us try our Deep Neural Net class with more layers, e.g. n_h $ = [320, 160, 80, 40, 20] $.

# %%
# Initialize the model
model = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
# This will display a recap of the different layers
print(model.modules)
# Out:
# <bound method Module.modules of DeepNeuralNet(
#   (combined_layers): Sequential(
#     (0): DenseReLU(
#       (fc): Linear(in_features=784, out_features=320, bias=True)
#     )
#     (1): DenseReLU(
#       (fc): Linear(in_features=320, out_features=160, bias=True)
#     )
#     (2): DenseReLU(
#       (fc): Linear(in_features=160, out_features=80, bias=True)
#     )
#     (3): DenseReLU(
#       (fc): Linear(in_features=80, out_features=40, bias=True)
#     )
#     (4): DenseReLU(
#       (fc): Linear(in_features=40, out_features=20, bias=True)
#     )
#     (5): DenseNoReLU(
#       (fc): Linear(in_features=20, out_features=10, bias=True)
#     )
#   )
# )>

# %% [markdown]
# ### Number of layers/neurons vs overfitting tradeoff
#
# In the previous noteboo, we raised a fairly important question: **what is the appropriate number of layers to use and how many neurons should we use on each layer?**
#
# We established that there is no fixed rule for how many layers should be used in a deep neural network. Instead, the number of layers, as well as the number of neurons in each layer, should be chosen based on the complexity of the task and the amount of available data.
#
# In general, deep neural networks with many layers (hundreds or even thousands) can learn very complex patterns in data, but they also require a large amount of data and computational resources to train. If the network is too deep, it may also be prone to overfitting, which can hinder its generalization performance on unseen data.
#
# On the other hand, shallow networks with fewer layers may be easier to train and require less data, but they may not be able to learn as complex patterns and may not achieve as high performance on some tasks.
#
# Finding the optimal number of layers and the optimal architecture of a deep neural network is often a trade-off between model complexity, computational resources, and performance, and requires some experimentation and model selection.

# %% [markdown]
# ### Before we continue, reworking the trainer() function to get performance curves
#
# We just add two lists keeping track of the train and test accuracies during training. Values will be appended to them during training. The entire code is then brought into a trainer() function for convenience.

# %%
def trainer(model, train_loader, test_loader):
    
    # History for train acc, test acc
    train_accs = []
    test_accs = []
    
    # Define optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr = 1e-2)

    # Training model
    num_epochs = 10
    for epoch in range(num_epochs):

        # Go trough all samples in train dataset
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            # Get from dataloader and send to device
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)

            # Compute loss
            loss = torch.nn.functional.cross_entropy(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Display
            if (i+1) % 25 == 0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Train Loss: {loss.item():.4f}')

        # Compute model train accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in train_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        train_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Accuracy: {train_accuracy:.4f}')
        train_accs.append(train_accuracy)
        
        # Compute model test accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in test_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        test_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {test_accuracy:.4f}')
        test_accs.append(test_accuracy)
        
    # Return
    return train_accs, test_accs

# %% [markdown]
# Let us now try to train three different models:
# - One model with 6 layers (n_h = [320, 160, 80, 40, 20]),
# - One model with three layers (n_h = [400, 200]),
# - And one model with three layers, but smaller ones (n_h = [40, 20]).

# %%
# Train a first model with 6 layers
model1 = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
train_accs1, test_accs1 = trainer(model1, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.6793
# Epoch [1/10], Step [50/235], Train Loss: 0.4531
# Epoch [1/10], Step [75/235], Train Loss: 0.3510
# Epoch [1/10], Step [100/235], Train Loss: 0.2221
# Epoch [1/10], Step [125/235], Train Loss: 0.2517
# Epoch [1/10], Step [150/235], Train Loss: 0.3106
# Epoch [1/10], Step [175/235], Train Loss: 0.2506
# Epoch [1/10], Step [200/235], Train Loss: 0.1466
# Epoch [1/10], Step [225/235], Train Loss: 0.0975
# Epoch [1/10], Train Accuracy: 0.9612
# Epoch [1/10], Test Accuracy: 0.9553
# Epoch [2/10], Step [25/235], Train Loss: 0.1542
# Epoch [2/10], Step [50/235], Train Loss: 0.1361
# Epoch [2/10], Step [75/235], Train Loss: 0.1590
# Epoch [2/10], Step [100/235], Train Loss: 0.1640
# Epoch [2/10], Step [125/235], Train Loss: 0.1050
# Epoch [2/10], Step [150/235], Train Loss: 0.1948
# Epoch [2/10], Step [175/235], Train Loss: 0.1406
# Epoch [2/10], Step [200/235], Train Loss: 0.1206
# Epoch [2/10], Step [225/235], Train Loss: 0.2227
# Epoch [2/10], Train Accuracy: 0.9689
# Epoch [2/10], Test Accuracy: 0.9603
# Epoch [3/10], Step [25/235], Train Loss: 0.2176
# Epoch [3/10], Step [50/235], Train Loss: 0.0377
# Epoch [3/10], Step [75/235], Train Loss: 0.1066
# Epoch [3/10], Step [100/235], Train Loss: 0.0890
# Epoch [3/10], Step [125/235], Train Loss: 0.0825
# Epoch [3/10], Step [150/235], Train Loss: 0.0685
# Epoch [3/10], Step [175/235], Train Loss: 0.1562
# Epoch [3/10], Step [200/235], Train Loss: 0.1652
# Epoch [3/10], Step [225/235], Train Loss: 0.0961
# Epoch [3/10], Train Accuracy: 0.9762
# Epoch [3/10], Test Accuracy: 0.9669
# Epoch [4/10], Step [25/235], Train Loss: 0.0707
# Epoch [4/10], Step [50/235], Train Loss: 0.0760
# Epoch [4/10], Step [75/235], Train Loss: 0.0836
# Epoch [4/10], Step [100/235], Train Loss: 0.0557
# Epoch [4/10], Step [125/235], Train Loss: 0.1224
# Epoch [4/10], Step [150/235], Train Loss: 0.0545
# Epoch [4/10], Step [175/235], Train Loss: 0.0418
# Epoch [4/10], Step [200/235], Train Loss: 0.1034
# Epoch [4/10], Step [225/235], Train Loss: 0.1187
# Epoch [4/10], Train Accuracy: 0.9817
# Epoch [4/10], Test Accuracy: 0.9736
# Epoch [5/10], Step [25/235], Train Loss: 0.0470
# Epoch [5/10], Step [50/235], Train Loss: 0.0900
# Epoch [5/10], Step [75/235], Train Loss: 0.1135
# Epoch [5/10], Step [100/235], Train Loss: 0.0562
# Epoch [5/10], Step [125/235], Train Loss: 0.0552
# Epoch [5/10], Step [150/235], Train Loss: 0.0482
# Epoch [5/10], Step [175/235], Train Loss: 0.0701
# Epoch [5/10], Step [200/235], Train Loss: 0.0969
# Epoch [5/10], Step [225/235], Train Loss: 0.1232
# Epoch [5/10], Train Accuracy: 0.9806
# Epoch [5/10], Test Accuracy: 0.9696
# Epoch [6/10], Step [25/235], Train Loss: 0.0521
# Epoch [6/10], Step [50/235], Train Loss: 0.0215
# Epoch [6/10], Step [75/235], Train Loss: 0.0226
# Epoch [6/10], Step [100/235], Train Loss: 0.0654
# Epoch [6/10], Step [125/235], Train Loss: 0.0515
# Epoch [6/10], Step [150/235], Train Loss: 0.0556
# Epoch [6/10], Step [175/235], Train Loss: 0.0421
# Epoch [6/10], Step [200/235], Train Loss: 0.0816
# Epoch [6/10], Step [225/235], Train Loss: 0.1074
# Epoch [6/10], Train Accuracy: 0.9841
# Epoch [6/10], Test Accuracy: 0.9711
# Epoch [7/10], Step [25/235], Train Loss: 0.0458
# Epoch [7/10], Step [50/235], Train Loss: 0.0383
# Epoch [7/10], Step [75/235], Train Loss: 0.0916
# Epoch [7/10], Step [100/235], Train Loss: 0.0718
# Epoch [7/10], Step [125/235], Train Loss: 0.0367
# Epoch [7/10], Step [150/235], Train Loss: 0.0528
# Epoch [7/10], Step [175/235], Train Loss: 0.0727
# Epoch [7/10], Step [200/235], Train Loss: 0.0339
# Epoch [7/10], Step [225/235], Train Loss: 0.0655
# Epoch [7/10], Train Accuracy: 0.9845
# Epoch [7/10], Test Accuracy: 0.9725
# Epoch [8/10], Step [25/235], Train Loss: 0.0904
# Epoch [8/10], Step [50/235], Train Loss: 0.0377
# Epoch [8/10], Step [75/235], Train Loss: 0.0937
# Epoch [8/10], Step [100/235], Train Loss: 0.0508
# Epoch [8/10], Step [125/235], Train Loss: 0.1629
# Epoch [8/10], Step [150/235], Train Loss: 0.1279
# Epoch [8/10], Step [175/235], Train Loss: 0.0766
# Epoch [8/10], Step [200/235], Train Loss: 0.0785
# Epoch [8/10], Step [225/235], Train Loss: 0.1445
# Epoch [8/10], Train Accuracy: 0.9799
# Epoch [8/10], Test Accuracy: 0.9694
# Epoch [9/10], Step [25/235], Train Loss: 0.0698
# Epoch [9/10], Step [50/235], Train Loss: 0.1079
# Epoch [9/10], Step [75/235], Train Loss: 0.0680
# Epoch [9/10], Step [100/235], Train Loss: 0.0573
# Epoch [9/10], Step [125/235], Train Loss: 0.0742
# Epoch [9/10], Step [150/235], Train Loss: 0.0707
# Epoch [9/10], Step [175/235], Train Loss: 0.0865
# Epoch [9/10], Step [200/235], Train Loss: 0.0407
# Epoch [9/10], Step [225/235], Train Loss: 0.0624
# Epoch [9/10], Train Accuracy: 0.9841
# Epoch [9/10], Test Accuracy: 0.9703
# Epoch [10/10], Step [25/235], Train Loss: 0.1359
# Epoch [10/10], Step [50/235], Train Loss: 0.0330
# Epoch [10/10], Step [75/235], Train Loss: 0.0243
# Epoch [10/10], Step [100/235], Train Loss: 0.1136
# Epoch [10/10], Step [125/235], Train Loss: 0.0277
# Epoch [10/10], Step [150/235], Train Loss: 0.0220
# Epoch [10/10], Step [175/235], Train Loss: 0.0411
# Epoch [10/10], Step [200/235], Train Loss: 0.0529
# Epoch [10/10], Step [225/235], Train Loss: 0.1023
# Epoch [10/10], Train Accuracy: 0.9846
# Epoch [10/10], Test Accuracy: 0.9687

# %%
# Train a second model with 3 layers
model2 = DeepNeuralNet(n_x = 784, n_h = [400, 200], n_y = 10).to(device)
train_accs2, test_accs2 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.3711
# Epoch [1/10], Step [50/235], Train Loss: 0.3153
# Epoch [1/10], Step [75/235], Train Loss: 0.2018
# Epoch [1/10], Step [100/235], Train Loss: 0.1638
# Epoch [1/10], Step [125/235], Train Loss: 0.1930
# Epoch [1/10], Step [150/235], Train Loss: 0.0776
# Epoch [1/10], Step [175/235], Train Loss: 0.1185
# Epoch [1/10], Step [200/235], Train Loss: 0.2093
# Epoch [1/10], Step [225/235], Train Loss: 0.1503
# Epoch [1/10], Train Accuracy: 0.9605
# Epoch [1/10], Test Accuracy: 0.9547
# Epoch [2/10], Step [25/235], Train Loss: 0.1044
# Epoch [2/10], Step [50/235], Train Loss: 0.1015
# Epoch [2/10], Step [75/235], Train Loss: 0.1160
# Epoch [2/10], Step [100/235], Train Loss: 0.1077
# Epoch [2/10], Step [125/235], Train Loss: 0.0901
# Epoch [2/10], Step [150/235], Train Loss: 0.1171
# Epoch [2/10], Step [175/235], Train Loss: 0.1462
# Epoch [2/10], Step [200/235], Train Loss: 0.0782
# Epoch [2/10], Step [225/235], Train Loss: 0.1200
# Epoch [2/10], Train Accuracy: 0.9650
# Epoch [2/10], Test Accuracy: 0.9526
# Epoch [3/10], Step [25/235], Train Loss: 0.0513
# Epoch [3/10], Step [50/235], Train Loss: 0.0238
# Epoch [3/10], Step [75/235], Train Loss: 0.0675
# Epoch [3/10], Step [100/235], Train Loss: 0.1039
# Epoch [3/10], Step [125/235], Train Loss: 0.0734
# Epoch [3/10], Step [150/235], Train Loss: 0.0643
# Epoch [3/10], Step [175/235], Train Loss: 0.0965
# Epoch [3/10], Step [200/235], Train Loss: 0.1773
# Epoch [3/10], Step [225/235], Train Loss: 0.0802
# Epoch [3/10], Train Accuracy: 0.9708
# Epoch [3/10], Test Accuracy: 0.9629
# Epoch [4/10], Step [25/235], Train Loss: 0.0428
# Epoch [4/10], Step [50/235], Train Loss: 0.0639
# Epoch [4/10], Step [75/235], Train Loss: 0.0791
# Epoch [4/10], Step [100/235], Train Loss: 0.1149
# Epoch [4/10], Step [125/235], Train Loss: 0.0790
# Epoch [4/10], Step [150/235], Train Loss: 0.0363
# Epoch [4/10], Step [175/235], Train Loss: 0.0755
# Epoch [4/10], Step [200/235], Train Loss: 0.0265
# Epoch [4/10], Step [225/235], Train Loss: 0.0681
# Epoch [4/10], Train Accuracy: 0.9711
# Epoch [4/10], Test Accuracy: 0.9610
# Epoch [5/10], Step [25/235], Train Loss: 0.1156
# Epoch [5/10], Step [50/235], Train Loss: 0.0626
# Epoch [5/10], Step [75/235], Train Loss: 0.1540
# Epoch [5/10], Step [100/235], Train Loss: 0.0351
# Epoch [5/10], Step [125/235], Train Loss: 0.1541
# Epoch [5/10], Step [150/235], Train Loss: 0.0891
# Epoch [5/10], Step [175/235], Train Loss: 0.1001
# Epoch [5/10], Step [200/235], Train Loss: 0.0713
# Epoch [5/10], Step [225/235], Train Loss: 0.0599
# Epoch [5/10], Train Accuracy: 0.9812
# Epoch [5/10], Test Accuracy: 0.9673
# Epoch [6/10], Step [25/235], Train Loss: 0.0538
# Epoch [6/10], Step [50/235], Train Loss: 0.0429
# Epoch [6/10], Step [75/235], Train Loss: 0.0886
# Epoch [6/10], Step [100/235], Train Loss: 0.1777
# Epoch [6/10], Step [125/235], Train Loss: 0.0536
# Epoch [6/10], Step [150/235], Train Loss: 0.0522
# Epoch [6/10], Step [175/235], Train Loss: 0.0557
# Epoch [6/10], Step [200/235], Train Loss: 0.1576
# Epoch [6/10], Step [225/235], Train Loss: 0.0989
# Epoch [6/10], Train Accuracy: 0.9849
# Epoch [6/10], Test Accuracy: 0.9703
# Epoch [7/10], Step [25/235], Train Loss: 0.0496
# Epoch [7/10], Step [50/235], Train Loss: 0.0603
# Epoch [7/10], Step [75/235], Train Loss: 0.1337
# Epoch [7/10], Step [100/235], Train Loss: 0.0960
# Epoch [7/10], Step [125/235], Train Loss: 0.1037
# Epoch [7/10], Step [150/235], Train Loss: 0.0558
# Epoch [7/10], Step [175/235], Train Loss: 0.0635
# Epoch [7/10], Step [200/235], Train Loss: 0.0593
# Epoch [7/10], Step [225/235], Train Loss: 0.0564
# Epoch [7/10], Train Accuracy: 0.9804
# Epoch [7/10], Test Accuracy: 0.9694
# Epoch [8/10], Step [25/235], Train Loss: 0.0748
# Epoch [8/10], Step [50/235], Train Loss: 0.0721
# Epoch [8/10], Step [75/235], Train Loss: 0.0608
# Epoch [8/10], Step [100/235], Train Loss: 0.1221
# Epoch [8/10], Step [125/235], Train Loss: 0.0437
# Epoch [8/10], Step [150/235], Train Loss: 0.0560
# Epoch [8/10], Step [175/235], Train Loss: 0.0502
# Epoch [8/10], Step [200/235], Train Loss: 0.1005
# Epoch [8/10], Step [225/235], Train Loss: 0.0862
# Epoch [8/10], Train Accuracy: 0.9835
# Epoch [8/10], Test Accuracy: 0.9676
# Epoch [9/10], Step [25/235], Train Loss: 0.1039
# Epoch [9/10], Step [50/235], Train Loss: 0.0670
# Epoch [9/10], Step [75/235], Train Loss: 0.0292
# Epoch [9/10], Step [100/235], Train Loss: 0.0924
# Epoch [9/10], Step [125/235], Train Loss: 0.1292
# Epoch [9/10], Step [150/235], Train Loss: 0.1165
# Epoch [9/10], Step [175/235], Train Loss: 0.0635
# Epoch [9/10], Step [200/235], Train Loss: 0.0372
# Epoch [9/10], Step [225/235], Train Loss: 0.1602
# Epoch [9/10], Train Accuracy: 0.9802
# Epoch [9/10], Test Accuracy: 0.9653
# Epoch [10/10], Step [25/235], Train Loss: 0.0552
# Epoch [10/10], Step [50/235], Train Loss: 0.0541
# Epoch [10/10], Step [75/235], Train Loss: 0.0365
# Epoch [10/10], Step [100/235], Train Loss: 0.0777
# Epoch [10/10], Step [125/235], Train Loss: 0.0589
# Epoch [10/10], Step [150/235], Train Loss: 0.1570
# Epoch [10/10], Step [175/235], Train Loss: 0.1278
# Epoch [10/10], Step [200/235], Train Loss: 0.0265
# Epoch [10/10], Step [225/235], Train Loss: 0.0551
# Epoch [10/10], Train Accuracy: 0.9832
# Epoch [10/10], Test Accuracy: 0.9662

# %%
# Train a second model with 3 layers
model3 = DeepNeuralNet(n_x = 784, n_h = [40, 20], n_y = 10).to(device)
train_accs3, test_accs3 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.0669
# Epoch [1/10], Step [50/235], Train Loss: 0.0383
# Epoch [1/10], Step [75/235], Train Loss: 0.0648
# Epoch [1/10], Step [100/235], Train Loss: 0.1199
# Epoch [1/10], Step [125/235], Train Loss: 0.0876
# Epoch [1/10], Step [150/235], Train Loss: 0.1173
# Epoch [1/10], Step [175/235], Train Loss: 0.0751
# Epoch [1/10], Step [200/235], Train Loss: 0.1500
# Epoch [1/10], Step [225/235], Train Loss: 0.1139
# Epoch [1/10], Train Accuracy: 0.9804
# Epoch [1/10], Test Accuracy: 0.9672
# Epoch [2/10], Step [25/235], Train Loss: 0.0550
# Epoch [2/10], Step [50/235], Train Loss: 0.0473
# Epoch [2/10], Step [75/235], Train Loss: 0.0270
# Epoch [2/10], Step [100/235], Train Loss: 0.0853
# Epoch [2/10], Step [125/235], Train Loss: 0.1101
# Epoch [2/10], Step [150/235], Train Loss: 0.0649
# Epoch [2/10], Step [175/235], Train Loss: 0.1213
# Epoch [2/10], Step [200/235], Train Loss: 0.0923
# Epoch [2/10], Step [225/235], Train Loss: 0.1459
# Epoch [2/10], Train Accuracy: 0.9794
# Epoch [2/10], Test Accuracy: 0.9641
# Epoch [3/10], Step [25/235], Train Loss: 0.0668
# Epoch [3/10], Step [50/235], Train Loss: 0.0865
# Epoch [3/10], Step [75/235], Train Loss: 0.0607
# Epoch [3/10], Step [100/235], Train Loss: 0.1039
# Epoch [3/10], Step [125/235], Train Loss: 0.0832
# Epoch [3/10], Step [150/235], Train Loss: 0.0535
# Epoch [3/10], Step [175/235], Train Loss: 0.0867
# Epoch [3/10], Step [200/235], Train Loss: 0.0901
# Epoch [3/10], Step [225/235], Train Loss: 0.0700
# Epoch [3/10], Train Accuracy: 0.9844
# Epoch [3/10], Test Accuracy: 0.9668
# Epoch [4/10], Step [25/235], Train Loss: 0.0806
# Epoch [4/10], Step [50/235], Train Loss: 0.0379
# Epoch [4/10], Step [75/235], Train Loss: 0.0127
# Epoch [4/10], Step [100/235], Train Loss: 0.0548
# Epoch [4/10], Step [125/235], Train Loss: 0.0957
# Epoch [4/10], Step [150/235], Train Loss: 0.1008
# Epoch [4/10], Step [175/235], Train Loss: 0.0727
# Epoch [4/10], Step [200/235], Train Loss: 0.0147
# Epoch [4/10], Step [225/235], Train Loss: 0.1623
# Epoch [4/10], Train Accuracy: 0.9845
# Epoch [4/10], Test Accuracy: 0.9725
# Epoch [5/10], Step [25/235], Train Loss: 0.0609
# Epoch [5/10], Step [50/235], Train Loss: 0.0365
# Epoch [5/10], Step [75/235], Train Loss: 0.1012
# Epoch [5/10], Step [100/235], Train Loss: 0.0362
# Epoch [5/10], Step [125/235], Train Loss: 0.0718
# Epoch [5/10], Step [150/235], Train Loss: 0.0628
# Epoch [5/10], Step [175/235], Train Loss: 0.1041
# Epoch [5/10], Step [200/235], Train Loss: 0.1749
# Epoch [5/10], Step [225/235], Train Loss: 0.0889
# Epoch [5/10], Train Accuracy: 0.9848
# Epoch [5/10], Test Accuracy: 0.9704
# Epoch [6/10], Step [25/235], Train Loss: 0.0529
# Epoch [6/10], Step [50/235], Train Loss: 0.0327
# Epoch [6/10], Step [75/235], Train Loss: 0.0772
# Epoch [6/10], Step [100/235], Train Loss: 0.0683
# Epoch [6/10], Step [125/235], Train Loss: 0.0438
# Epoch [6/10], Step [150/235], Train Loss: 0.0729
# Epoch [6/10], Step [175/235], Train Loss: 0.0571
# Epoch [6/10], Step [200/235], Train Loss: 0.0963
# Epoch [6/10], Step [225/235], Train Loss: 0.0448
# Epoch [6/10], Train Accuracy: 0.9872
# Epoch [6/10], Test Accuracy: 0.9716
# Epoch [7/10], Step [25/235], Train Loss: 0.0374
# Epoch [7/10], Step [50/235], Train Loss: 0.0437
# Epoch [7/10], Step [75/235], Train Loss: 0.0883
# Epoch [7/10], Step [100/235], Train Loss: 0.0284
# Epoch [7/10], Step [125/235], Train Loss: 0.0264
# Epoch [7/10], Step [150/235], Train Loss: 0.0226
# Epoch [7/10], Step [175/235], Train Loss: 0.0158
# Epoch [7/10], Step [200/235], Train Loss: 0.0281
# Epoch [7/10], Step [225/235], Train Loss: 0.0486
# Epoch [7/10], Train Accuracy: 0.9863
# Epoch [7/10], Test Accuracy: 0.9718
# Epoch [8/10], Step [25/235], Train Loss: 0.0612
# Epoch [8/10], Step [50/235], Train Loss: 0.0632
# Epoch [8/10], Step [75/235], Train Loss: 0.0336
# Epoch [8/10], Step [100/235], Train Loss: 0.0394
# Epoch [8/10], Step [125/235], Train Loss: 0.1007
# Epoch [8/10], Step [150/235], Train Loss: 0.1132
# Epoch [8/10], Step [175/235], Train Loss: 0.0157
# Epoch [8/10], Step [200/235], Train Loss: 0.0473
# Epoch [8/10], Step [225/235], Train Loss: 0.1356
# Epoch [8/10], Train Accuracy: 0.9863
# Epoch [8/10], Test Accuracy: 0.9695
# Epoch [9/10], Step [25/235], Train Loss: 0.0222
# Epoch [9/10], Step [50/235], Train Loss: 0.0337
# Epoch [9/10], Step [75/235], Train Loss: 0.0410
# Epoch [9/10], Step [100/235], Train Loss: 0.0620
# Epoch [9/10], Step [125/235], Train Loss: 0.0290
# Epoch [9/10], Step [150/235], Train Loss: 0.0348
# Epoch [9/10], Step [175/235], Train Loss: 0.0189
# Epoch [9/10], Step [200/235], Train Loss: 0.0687
# Epoch [9/10], Step [225/235], Train Loss: 0.0679
# Epoch [9/10], Train Accuracy: 0.9889
# Epoch [9/10], Test Accuracy: 0.9723
# Epoch [10/10], Step [25/235], Train Loss: 0.0219
# Epoch [10/10], Step [50/235], Train Loss: 0.0299
# Epoch [10/10], Step [75/235], Train Loss: 0.0826
# Epoch [10/10], Step [100/235], Train Loss: 0.0373
# Epoch [10/10], Step [125/235], Train Loss: 0.0200
# Epoch [10/10], Step [150/235], Train Loss: 0.0145
# Epoch [10/10], Step [175/235], Train Loss: 0.0460
# Epoch [10/10], Step [200/235], Train Loss: 0.0958
# Epoch [10/10], Step [225/235], Train Loss: 0.0976
# Epoch [10/10], Train Accuracy: 0.9859
# Epoch [10/10], Test Accuracy: 0.9722

# %% [markdown]
# The first thing we can observe is that the training time seems to scale with the number of trainable parameters (total number of neurons in all layers combined togather).
#
# Looking at the performance curves below, we can see that all three models are able to train correctly without overfitting. They however achieve a close performance, therefore hinting at the fact that going for deep neural networks, is not necessarily better.
#
# In fact, we could obtain very similar results with less layers and smaller sizes.
#
# Note that this is a particular case, here, because MNIST is a very nice dataset and very hard to underfit or overfit. In the future, however, it would be a good practice to check different sizes for you deep neural network architecture and control whether you are underfitting, overfitting or fitting the data just right.
#
# As mentioned in the notebook 7 from W2, it would be also good practice to keep saves of your models during training times and eventually use the best model you have obtained after you have tried a few different hyperparameters (number of layers, number of neurons, learning rates, etc.).

# %%
plt.figure(figsize = (10, 7))
plt.plot(train_accs1, "r-", label = "Model 1 train acc.")
plt.plot(test_accs1, "b-", label = "Model 1 test acc.")
plt.plot(train_accs2, "r--", label = "Model 2 train acc.")
plt.plot(test_accs2, "b--", label = "Model 2 test acc.")
plt.plot(train_accs3, "r:", label = "Model 3 train acc.")
plt.plot(test_accs3, "b:", label = "Model 3 test acc.")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# ### What's next?
#
# In this notebook, we were able to perform image recognition using Deep Neural Networks and obtained a rather good test accuracy of 96% after training. While this appears as not too bad, this mainly has to do with MNIST being a nice dataset. In  practice, when it comes to processing images passed as inputs, the fully connected/Linear layers are not really the best choice, and they might rapidly struggle once the images become more sophisticated (higher resolution than 28x28, no longer greyscale but RGB, etc.).
#
# Next week, we will discuss the convolution operation, which is a different operation than the $ Wx + b $ one, which can be used as a layer in Neural Networks, and see why it is far superior when it comes to processing images.
