# %% [markdown]
# # 7. PyTorch Basics - Good practices in Deep Learning Projects
#
# ### About this notebook
#
# This notebook was used in the 50.039 Deep Learning course at the Singapore University of Technology and Design.
#
# **Author:** Matthieu DE MARI (matthieu_demari@sutd.edu.sg)
#
# **Version:** 1.0 (27/12/2022)
#
# **Requirements:**
# - Python 3 (tested on v3.9.6)
# - Matplotlib (tested on v3.5.1)
# - Numpy (tested on v1.22.1)
# - Time
# - Torch (tested on v1.13.0)
# - Torchmetrics (tested on v0.11.0)

# %% [markdown]
# ### Imports and CUDA

# %%
# Matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
# Numpy
import numpy as np
# Torch
import torch
import torchvision
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Compose, Normalize
from torchvision.datasets import MNIST

# %%
# Use GPU if available, else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### The MNIST Dataset
#
# As in the previous notebook

# %%
# Define transform to convert images to tensors and normalize them
transform_data = Compose([ToTensor(),
                          Normalize((0.1307,), (0.3081,))])

# Load the data
batch_size = 256
train_dataset = MNIST(root='./mnist/', train = True, download = True, transform = transform_data)
test_dataset = MNIST(root='./mnist/', train = False, download = True, transform = transform_data)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)

# %% [markdown]
# ### Our deep neural network
#
# As in the previous notebook.
#
# However, we have stremalined the DeepNeuralNet class and its init method so that it can work with any number of elements in the list n_h (instead of just 3). The Sequential will then adjust automatically to produce any appropriate number of DenseReLU layers and finish with a single DenseSoftmax one.

# %%
class DenseReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        # Using ReLU operation as activation after
        return torch.relu(self.fc(x))

# %%
class DenseNoReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        return self.fc(x)

# %%
class DeepNeuralNet(torch.nn.Module):
    def __init__(self, n_x, n_h, n_y):
        super().__init__()
        # Define the correct number of Dense + ReLU layers based on n_h,
        # followed by one final Dense + Softmax layer
        values = [n_x] + n_h
        self.processing_layers = [DenseReLU(values[i], values[i + 1]) for i in range(len(values) - 1)]
        self.processing_layers += [DenseNoReLU(n_h[-1], n_y)]
        
        # Combine all layers
        # Important: note the * symbol before the list of layers in self.processing_layers
        # Not sure what it does? Check the *args and **kwargs concepts in Python.
        self.combined_layers = torch.nn.Sequential(*self.processing_layers)

    
    def forward(self, x):
        # Flatten images (transform them from 28x28 2D matrices to 784 1D vectors)
        x = x.view(x.size(0), -1)
        # Pass through all four layers
        out = self.combined_layers(x)
        return out

# %% [markdown]
# Let us try our Deep Neural Net class with more layers, e.g. n_h $ = [320, 160, 80, 40, 20] $.

# %%
# Initialize the model
model = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
# This will display a recap of the different layers
print(model.modules)
# Out:
# <bound method Module.modules of DeepNeuralNet(
#   (combined_layers): Sequential(
#     (0): DenseReLU(
#       (fc): Linear(in_features=784, out_features=320, bias=True)
#     )
#     (1): DenseReLU(
#       (fc): Linear(in_features=320, out_features=160, bias=True)
#     )
#     (2): DenseReLU(
#       (fc): Linear(in_features=160, out_features=80, bias=True)
#     )
#     (3): DenseReLU(
#       (fc): Linear(in_features=80, out_features=40, bias=True)
#     )
#     (4): DenseReLU(
#       (fc): Linear(in_features=40, out_features=20, bias=True)
#     )
#     (5): DenseNoReLU(
#       (fc): Linear(in_features=20, out_features=10, bias=True)
#     )
#   )
# )>

# %% [markdown]
# ### Number of layers/neurons vs overfitting tradeoff
#
# In the previous noteboo, we raised a fairly important question: **what is the appropriate number of layers to use and how many neurons should we use on each layer?**
#
# We established that there is no fixed rule for how many layers should be used in a deep neural network. Instead, the number of layers, as well as the number of neurons in each layer, should be chosen based on the complexity of the task and the amount of available data.
#
# In general, deep neural networks with many layers (hundreds or even thousands) can learn very complex patterns in data, but they also require a large amount of data and computational resources to train. If the network is too deep, it may also be prone to overfitting, which can hinder its generalization performance on unseen data.
#
# On the other hand, shallow networks with fewer layers may be easier to train and require less data, but they may not be able to learn as complex patterns and may not achieve as high performance on some tasks.
#
# Finding the optimal number of layers and the optimal architecture of a deep neural network is often a trade-off between model complexity, computational resources, and performance, and requires some experimentation and model selection.

# %% [markdown]
# ### Before we continue, reworking the trainer() fucntion to get performance curves
#
# We just add two lists keeping track of the train and test accuracies during training. Values will be appended to them during training. The entire code is then brought into a trainer() function for convenience.

# %%
def trainer(model, train_loader, test_loader):
    
    # History for train acc, test acc
    train_accs = []
    test_accs = []
    
    # Define optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr = 1e-2)

    # Training model
    num_epochs = 10
    for epoch in range(num_epochs):

        # Go trough all samples in train dataset
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            # Get from dataloader and send to device
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)

            # Compute loss
            loss = torch.nn.functional.cross_entropy(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Display
            if (i+1) % 25 == 0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Train Loss: {loss.item():.4f}')

        # Compute model train accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in train_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        train_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Accuracy: {train_accuracy:.4f}')
        train_accs.append(train_accuracy)
        
        # Compute model test accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in test_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        test_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {test_accuracy:.4f}')
        test_accs.append(test_accuracy)
        
    # Return
    return train_accs, test_accs

# %% [markdown]
# Let us now try to train three different models:
# - One model with 6 layers (n_h = [320, 160, 80, 40, 20]),
# - One model with three layers (n_h = [400, 200]),
# - And one model with three layers, but smaller ones (n_h = [40, 20]).

# %%
# Train a first model with 6 layers
model1 = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
train_accs1, test_accs1 = trainer(model1, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.8360
# Epoch [1/10], Step [50/235], Train Loss: 0.3783
# Epoch [1/10], Step [75/235], Train Loss: 0.3786
# Epoch [1/10], Step [100/235], Train Loss: 0.3275
# Epoch [1/10], Step [125/235], Train Loss: 0.2639
# Epoch [1/10], Step [150/235], Train Loss: 0.2908
# Epoch [1/10], Step [175/235], Train Loss: 0.2547
# Epoch [1/10], Step [200/235], Train Loss: 0.1209
# Epoch [1/10], Step [225/235], Train Loss: 0.1512
# Epoch [1/10], Train Accuracy: 0.9591
# Epoch [1/10], Test Accuracy: 0.9537
# Epoch [2/10], Step [25/235], Train Loss: 0.1093
# Epoch [2/10], Step [50/235], Train Loss: 0.1450
# Epoch [2/10], Step [75/235], Train Loss: 0.2259
# Epoch [2/10], Step [100/235], Train Loss: 0.1033
# Epoch [2/10], Step [125/235], Train Loss: 0.2084
# Epoch [2/10], Step [150/235], Train Loss: 0.0718
# Epoch [2/10], Step [175/235], Train Loss: 0.1519
# Epoch [2/10], Step [200/235], Train Loss: 0.1627
# Epoch [2/10], Step [225/235], Train Loss: 0.1939
# Epoch [2/10], Train Accuracy: 0.9680
# Epoch [2/10], Test Accuracy: 0.9626
# Epoch [3/10], Step [25/235], Train Loss: 0.1191
# Epoch [3/10], Step [50/235], Train Loss: 0.1774
# Epoch [3/10], Step [75/235], Train Loss: 0.0626
# Epoch [3/10], Step [100/235], Train Loss: 0.1339
# Epoch [3/10], Step [125/235], Train Loss: 0.1162
# Epoch [3/10], Step [150/235], Train Loss: 0.0656
# Epoch [3/10], Step [175/235], Train Loss: 0.0938
# Epoch [3/10], Step [200/235], Train Loss: 0.1373
# Epoch [3/10], Step [225/235], Train Loss: 0.1818
# Epoch [3/10], Train Accuracy: 0.9757
# Epoch [3/10], Test Accuracy: 0.9638
# Epoch [4/10], Step [25/235], Train Loss: 0.0871
# Epoch [4/10], Step [50/235], Train Loss: 0.1042
# Epoch [4/10], Step [75/235], Train Loss: 0.0759
# Epoch [4/10], Step [100/235], Train Loss: 0.0644
# Epoch [4/10], Step [125/235], Train Loss: 0.0406
# Epoch [4/10], Step [150/235], Train Loss: 0.1328
# Epoch [4/10], Step [175/235], Train Loss: 0.0656
# Epoch [4/10], Step [200/235], Train Loss: 0.1732
# Epoch [4/10], Step [225/235], Train Loss: 0.0255
# Epoch [4/10], Train Accuracy: 0.9790
# Epoch [4/10], Test Accuracy: 0.9671
# Epoch [5/10], Step [25/235], Train Loss: 0.0610
# Epoch [5/10], Step [50/235], Train Loss: 0.0571
# Epoch [5/10], Step [75/235], Train Loss: 0.0731
# Epoch [5/10], Step [100/235], Train Loss: 0.0367
# Epoch [5/10], Step [125/235], Train Loss: 0.0506
# Epoch [5/10], Step [150/235], Train Loss: 0.0468
# Epoch [5/10], Step [175/235], Train Loss: 0.0891
# Epoch [5/10], Step [200/235], Train Loss: 0.0469
# Epoch [5/10], Step [225/235], Train Loss: 0.0489
# Epoch [5/10], Train Accuracy: 0.9838
# Epoch [5/10], Test Accuracy: 0.9701
# Epoch [6/10], Step [25/235], Train Loss: 0.0184
# Epoch [6/10], Step [50/235], Train Loss: 0.0965
# Epoch [6/10], Step [75/235], Train Loss: 0.0581
# Epoch [6/10], Step [100/235], Train Loss: 0.1618
# Epoch [6/10], Step [125/235], Train Loss: 0.1362
# Epoch [6/10], Step [150/235], Train Loss: 0.0945
# Epoch [6/10], Step [175/235], Train Loss: 0.0759
# Epoch [6/10], Step [200/235], Train Loss: 0.0616
# Epoch [6/10], Step [225/235], Train Loss: 0.0861
# Epoch [6/10], Train Accuracy: 0.9817
# Epoch [6/10], Test Accuracy: 0.9687
# Epoch [7/10], Step [25/235], Train Loss: 0.0608
# Epoch [7/10], Step [50/235], Train Loss: 0.0528
# Epoch [7/10], Step [75/235], Train Loss: 0.1118
# Epoch [7/10], Step [100/235], Train Loss: 0.0880
# Epoch [7/10], Step [125/235], Train Loss: 0.0245
# Epoch [7/10], Step [150/235], Train Loss: 0.0552
# Epoch [7/10], Step [175/235], Train Loss: 0.0331
# Epoch [7/10], Step [200/235], Train Loss: 0.0359
# Epoch [7/10], Step [225/235], Train Loss: 0.0527
# Epoch [7/10], Train Accuracy: 0.9815
# Epoch [7/10], Test Accuracy: 0.9691
# Epoch [8/10], Step [25/235], Train Loss: 0.0856
# Epoch [8/10], Step [50/235], Train Loss: 0.0398
# Epoch [8/10], Step [75/235], Train Loss: 0.0277
# Epoch [8/10], Step [100/235], Train Loss: 0.0756
# Epoch [8/10], Step [125/235], Train Loss: 0.0125
# Epoch [8/10], Step [150/235], Train Loss: 0.0521
# Epoch [8/10], Step [175/235], Train Loss: 0.0677
# Epoch [8/10], Step [200/235], Train Loss: 0.0513
# Epoch [8/10], Step [225/235], Train Loss: 0.0438
# Epoch [8/10], Train Accuracy: 0.9862
# Epoch [8/10], Test Accuracy: 0.9728
# Epoch [9/10], Step [25/235], Train Loss: 0.0746
# Epoch [9/10], Step [50/235], Train Loss: 0.0267
# Epoch [9/10], Step [75/235], Train Loss: 0.0133
# Epoch [9/10], Step [100/235], Train Loss: 0.0227
# Epoch [9/10], Step [125/235], Train Loss: 0.0186
# Epoch [9/10], Step [150/235], Train Loss: 0.0549
# Epoch [9/10], Step [175/235], Train Loss: 0.0384
# Epoch [9/10], Step [200/235], Train Loss: 0.0352
# Epoch [9/10], Step [225/235], Train Loss: 0.1057
# Epoch [9/10], Train Accuracy: 0.9858
# Epoch [9/10], Test Accuracy: 0.9725
# Epoch [10/10], Step [25/235], Train Loss: 0.0254
# Epoch [10/10], Step [50/235], Train Loss: 0.1037
# Epoch [10/10], Step [75/235], Train Loss: 0.0278
# Epoch [10/10], Step [100/235], Train Loss: 0.0367
# Epoch [10/10], Step [125/235], Train Loss: 0.0302
# Epoch [10/10], Step [150/235], Train Loss: 0.0705
# Epoch [10/10], Step [175/235], Train Loss: 0.0556
# Epoch [10/10], Step [200/235], Train Loss: 0.0689
# Epoch [10/10], Step [225/235], Train Loss: 0.0646
# Epoch [10/10], Train Accuracy: 0.9860
# Epoch [10/10], Test Accuracy: 0.9724

# %%
# Train a second model with 3 layers
model2 = DeepNeuralNet(n_x = 784, n_h = [400, 200], n_y = 10).to(device)
train_accs2, test_accs2 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.3207
# Epoch [1/10], Step [50/235], Train Loss: 0.2204
# Epoch [1/10], Step [75/235], Train Loss: 0.1640
# Epoch [1/10], Step [100/235], Train Loss: 0.2308
# Epoch [1/10], Step [125/235], Train Loss: 0.1624
# Epoch [1/10], Step [150/235], Train Loss: 0.1509
# Epoch [1/10], Step [175/235], Train Loss: 0.0704
# Epoch [1/10], Step [200/235], Train Loss: 0.2228
# Epoch [1/10], Step [225/235], Train Loss: 0.1299
# Epoch [1/10], Train Accuracy: 0.9606
# Epoch [1/10], Test Accuracy: 0.9551
# Epoch [2/10], Step [25/235], Train Loss: 0.2284
# Epoch [2/10], Step [50/235], Train Loss: 0.1542
# Epoch [2/10], Step [75/235], Train Loss: 0.1109
# Epoch [2/10], Step [100/235], Train Loss: 0.1344
# Epoch [2/10], Step [125/235], Train Loss: 0.0709
# Epoch [2/10], Step [150/235], Train Loss: 0.0752
# Epoch [2/10], Step [175/235], Train Loss: 0.1068
# Epoch [2/10], Step [200/235], Train Loss: 0.0873
# Epoch [2/10], Step [225/235], Train Loss: 0.0675
# Epoch [2/10], Train Accuracy: 0.9708
# Epoch [2/10], Test Accuracy: 0.9594
# Epoch [3/10], Step [25/235], Train Loss: 0.1076
# Epoch [3/10], Step [50/235], Train Loss: 0.1098
# Epoch [3/10], Step [75/235], Train Loss: 0.0960
# Epoch [3/10], Step [100/235], Train Loss: 0.0504
# Epoch [3/10], Step [125/235], Train Loss: 0.0735
# Epoch [3/10], Step [150/235], Train Loss: 0.0817
# Epoch [3/10], Step [175/235], Train Loss: 0.0572
# Epoch [3/10], Step [200/235], Train Loss: 0.1680
# Epoch [3/10], Step [225/235], Train Loss: 0.0847
# Epoch [3/10], Train Accuracy: 0.9786
# Epoch [3/10], Test Accuracy: 0.9694
# Epoch [4/10], Step [25/235], Train Loss: 0.0546
# Epoch [4/10], Step [50/235], Train Loss: 0.0779
# Epoch [4/10], Step [75/235], Train Loss: 0.1030
# Epoch [4/10], Step [100/235], Train Loss: 0.1677
# Epoch [4/10], Step [125/235], Train Loss: 0.0874
# Epoch [4/10], Step [150/235], Train Loss: 0.0991
# Epoch [4/10], Step [175/235], Train Loss: 0.1299
# Epoch [4/10], Step [200/235], Train Loss: 0.1185
# Epoch [4/10], Step [225/235], Train Loss: 0.0353
# Epoch [4/10], Train Accuracy: 0.9736
# Epoch [4/10], Test Accuracy: 0.9627
# Epoch [5/10], Step [25/235], Train Loss: 0.0816
# Epoch [5/10], Step [50/235], Train Loss: 0.1425
# Epoch [5/10], Step [75/235], Train Loss: 0.1193
# Epoch [5/10], Step [100/235], Train Loss: 0.0905
# Epoch [5/10], Step [125/235], Train Loss: 0.0419
# Epoch [5/10], Step [150/235], Train Loss: 0.1183
# Epoch [5/10], Step [175/235], Train Loss: 0.0566
# Epoch [5/10], Step [200/235], Train Loss: 0.0669
# Epoch [5/10], Step [225/235], Train Loss: 0.1658
# Epoch [5/10], Train Accuracy: 0.9771
# Epoch [5/10], Test Accuracy: 0.9651
# Epoch [6/10], Step [25/235], Train Loss: 0.0710
# Epoch [6/10], Step [50/235], Train Loss: 0.0625
# Epoch [6/10], Step [75/235], Train Loss: 0.1347
# Epoch [6/10], Step [100/235], Train Loss: 0.0886
# Epoch [6/10], Step [125/235], Train Loss: 0.0863
# Epoch [6/10], Step [150/235], Train Loss: 0.0935
# Epoch [6/10], Step [175/235], Train Loss: 0.0381
# Epoch [6/10], Step [200/235], Train Loss: 0.1843
# Epoch [6/10], Step [225/235], Train Loss: 0.0232
# Epoch [6/10], Train Accuracy: 0.9785
# Epoch [6/10], Test Accuracy: 0.9660
# Epoch [7/10], Step [25/235], Train Loss: 0.1056
# Epoch [7/10], Step [50/235], Train Loss: 0.1003
# Epoch [7/10], Step [75/235], Train Loss: 0.1035
# Epoch [7/10], Step [100/235], Train Loss: 0.0800
# Epoch [7/10], Step [125/235], Train Loss: 0.1177
# Epoch [7/10], Step [150/235], Train Loss: 0.0336
# Epoch [7/10], Step [175/235], Train Loss: 0.0507
# Epoch [7/10], Step [200/235], Train Loss: 0.0335
# Epoch [7/10], Step [225/235], Train Loss: 0.1094
# Epoch [7/10], Train Accuracy: 0.9799
# Epoch [7/10], Test Accuracy: 0.9649
# Epoch [8/10], Step [25/235], Train Loss: 0.0747
# Epoch [8/10], Step [50/235], Train Loss: 0.0377
# Epoch [8/10], Step [75/235], Train Loss: 0.0431
# Epoch [8/10], Step [100/235], Train Loss: 0.1182
# Epoch [8/10], Step [125/235], Train Loss: 0.0588
# Epoch [8/10], Step [150/235], Train Loss: 0.0466
# Epoch [8/10], Step [175/235], Train Loss: 0.0719
# Epoch [8/10], Step [200/235], Train Loss: 0.0343
# Epoch [8/10], Step [225/235], Train Loss: 0.2353
# Epoch [8/10], Train Accuracy: 0.9787
# Epoch [8/10], Test Accuracy: 0.9649
# Epoch [9/10], Step [25/235], Train Loss: 0.0986
# Epoch [9/10], Step [50/235], Train Loss: 0.0648
# Epoch [9/10], Step [75/235], Train Loss: 0.1577
# Epoch [9/10], Step [100/235], Train Loss: 0.0924
# Epoch [9/10], Step [125/235], Train Loss: 0.0622
# Epoch [9/10], Step [150/235], Train Loss: 0.1958
# Epoch [9/10], Step [175/235], Train Loss: 0.1327
# Epoch [9/10], Step [200/235], Train Loss: 0.0438
# Epoch [9/10], Step [225/235], Train Loss: 0.0370
# Epoch [9/10], Train Accuracy: 0.9832
# Epoch [9/10], Test Accuracy: 0.9694
# Epoch [10/10], Step [25/235], Train Loss: 0.0213
# Epoch [10/10], Step [50/235], Train Loss: 0.0554
# Epoch [10/10], Step [75/235], Train Loss: 0.0824
# Epoch [10/10], Step [100/235], Train Loss: 0.1334
# Epoch [10/10], Step [125/235], Train Loss: 0.0365
# Epoch [10/10], Step [150/235], Train Loss: 0.0350
# Epoch [10/10], Step [175/235], Train Loss: 0.0649
# Epoch [10/10], Step [200/235], Train Loss: 0.0946
# Epoch [10/10], Step [225/235], Train Loss: 0.0319
# Epoch [10/10], Train Accuracy: 0.9840
# Epoch [10/10], Test Accuracy: 0.9709

# %%
# Train a second model with 3 layers
model3 = DeepNeuralNet(n_x = 784, n_h = [40, 20], n_y = 10).to(device)
train_accs3, test_accs3 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.1191
# Epoch [1/10], Step [50/235], Train Loss: 0.0930
# Epoch [1/10], Step [75/235], Train Loss: 0.1014
# Epoch [1/10], Step [100/235], Train Loss: 0.0507
# Epoch [1/10], Step [125/235], Train Loss: 0.1088
# Epoch [1/10], Step [150/235], Train Loss: 0.1117
# Epoch [1/10], Step [175/235], Train Loss: 0.3225
# Epoch [1/10], Step [200/235], Train Loss: 0.0442
# Epoch [1/10], Step [225/235], Train Loss: 0.0839
# Epoch [1/10], Train Accuracy: 0.9765
# Epoch [1/10], Test Accuracy: 0.9635
# Epoch [2/10], Step [25/235], Train Loss: 0.0365
# Epoch [2/10], Step [50/235], Train Loss: 0.1122
# Epoch [2/10], Step [75/235], Train Loss: 0.0530
# Epoch [2/10], Step [100/235], Train Loss: 0.0542
# Epoch [2/10], Step [125/235], Train Loss: 0.1765
# Epoch [2/10], Step [150/235], Train Loss: 0.0394
# Epoch [2/10], Step [175/235], Train Loss: 0.1065
# Epoch [2/10], Step [200/235], Train Loss: 0.1265
# Epoch [2/10], Step [225/235], Train Loss: 0.1665
# Epoch [2/10], Train Accuracy: 0.9811
# Epoch [2/10], Test Accuracy: 0.9666
# Epoch [3/10], Step [25/235], Train Loss: 0.0411
# Epoch [3/10], Step [50/235], Train Loss: 0.1177
# Epoch [3/10], Step [75/235], Train Loss: 0.0616
# Epoch [3/10], Step [100/235], Train Loss: 0.0153
# Epoch [3/10], Step [125/235], Train Loss: 0.0737
# Epoch [3/10], Step [150/235], Train Loss: 0.0887
# Epoch [3/10], Step [175/235], Train Loss: 0.1203
# Epoch [3/10], Step [200/235], Train Loss: 0.0412
# Epoch [3/10], Step [225/235], Train Loss: 0.0310
# Epoch [3/10], Train Accuracy: 0.9889
# Epoch [3/10], Test Accuracy: 0.9749
# Epoch [4/10], Step [25/235], Train Loss: 0.0456
# Epoch [4/10], Step [50/235], Train Loss: 0.0203
# Epoch [4/10], Step [75/235], Train Loss: 0.1049
# Epoch [4/10], Step [100/235], Train Loss: 0.0416
# Epoch [4/10], Step [125/235], Train Loss: 0.0532
# Epoch [4/10], Step [150/235], Train Loss: 0.0326
# Epoch [4/10], Step [175/235], Train Loss: 0.0583
# Epoch [4/10], Step [200/235], Train Loss: 0.0828
# Epoch [4/10], Step [225/235], Train Loss: 0.1016
# Epoch [4/10], Train Accuracy: 0.9840
# Epoch [4/10], Test Accuracy: 0.9676
# Epoch [5/10], Step [25/235], Train Loss: 0.1342
# Epoch [5/10], Step [50/235], Train Loss: 0.0166
# Epoch [5/10], Step [75/235], Train Loss: 0.0372
# Epoch [5/10], Step [100/235], Train Loss: 0.0234
# Epoch [5/10], Step [125/235], Train Loss: 0.1024
# Epoch [5/10], Step [150/235], Train Loss: 0.0911
# Epoch [5/10], Step [175/235], Train Loss: 0.0664
# Epoch [5/10], Step [200/235], Train Loss: 0.0380
# Epoch [5/10], Step [225/235], Train Loss: 0.0107
# Epoch [5/10], Train Accuracy: 0.9863
# Epoch [5/10], Test Accuracy: 0.9719
# Epoch [6/10], Step [25/235], Train Loss: 0.0365
# Epoch [6/10], Step [50/235], Train Loss: 0.1342
# Epoch [6/10], Step [75/235], Train Loss: 0.0960
# Epoch [6/10], Step [100/235], Train Loss: 0.0592
# Epoch [6/10], Step [125/235], Train Loss: 0.0914
# Epoch [6/10], Step [150/235], Train Loss: 0.1442
# Epoch [6/10], Step [175/235], Train Loss: 0.0792
# Epoch [6/10], Step [200/235], Train Loss: 0.0509
# Epoch [6/10], Step [225/235], Train Loss: 0.1458
# Epoch [6/10], Train Accuracy: 0.9855
# Epoch [6/10], Test Accuracy: 0.9711
# Epoch [7/10], Step [25/235], Train Loss: 0.0232
# Epoch [7/10], Step [50/235], Train Loss: 0.1173
# Epoch [7/10], Step [75/235], Train Loss: 0.0366
# Epoch [7/10], Step [100/235], Train Loss: 0.0500
# Epoch [7/10], Step [125/235], Train Loss: 0.0543
# Epoch [7/10], Step [150/235], Train Loss: 0.0270
# Epoch [7/10], Step [175/235], Train Loss: 0.0400
# Epoch [7/10], Step [200/235], Train Loss: 0.0501
# Epoch [7/10], Step [225/235], Train Loss: 0.0469
# Epoch [7/10], Train Accuracy: 0.9840
# Epoch [7/10], Test Accuracy: 0.9684
# Epoch [8/10], Step [25/235], Train Loss: 0.0805
# Epoch [8/10], Step [50/235], Train Loss: 0.0184
# Epoch [8/10], Step [75/235], Train Loss: 0.0167
# Epoch [8/10], Step [100/235], Train Loss: 0.0330
# Epoch [8/10], Step [125/235], Train Loss: 0.0677
# Epoch [8/10], Step [150/235], Train Loss: 0.0863
# Epoch [8/10], Step [175/235], Train Loss: 0.0147
# Epoch [8/10], Step [200/235], Train Loss: 0.0419
# Epoch [8/10], Step [225/235], Train Loss: 0.0406
# Epoch [8/10], Train Accuracy: 0.9830
# Epoch [8/10], Test Accuracy: 0.9636
# Epoch [9/10], Step [25/235], Train Loss: 0.0418
# Epoch [9/10], Step [50/235], Train Loss: 0.0403
# Epoch [9/10], Step [75/235], Train Loss: 0.0210
# Epoch [9/10], Step [100/235], Train Loss: 0.0426
# Epoch [9/10], Step [125/235], Train Loss: 0.0286
# Epoch [9/10], Step [150/235], Train Loss: 0.1067
# Epoch [9/10], Step [175/235], Train Loss: 0.0446
# Epoch [9/10], Step [200/235], Train Loss: 0.0645
# Epoch [9/10], Step [225/235], Train Loss: 0.0824
# Epoch [9/10], Train Accuracy: 0.9859
# Epoch [9/10], Test Accuracy: 0.9691
# Epoch [10/10], Step [25/235], Train Loss: 0.0358
# Epoch [10/10], Step [50/235], Train Loss: 0.0904
# Epoch [10/10], Step [75/235], Train Loss: 0.0804
# Epoch [10/10], Step [100/235], Train Loss: 0.0792
# Epoch [10/10], Step [125/235], Train Loss: 0.0439
# Epoch [10/10], Step [150/235], Train Loss: 0.0849
# Epoch [10/10], Step [175/235], Train Loss: 0.0285
# Epoch [10/10], Step [200/235], Train Loss: 0.0339
# Epoch [10/10], Step [225/235], Train Loss: 0.0566
# Epoch [10/10], Train Accuracy: 0.9877
# Epoch [10/10], Test Accuracy: 0.9700

# %% [markdown]
# The first thing we can observe is that the training time seems to scale with the number of trainable parameters (total number of neurons in all layers combined togather).
#
# Looking at the performance curves below, we can see that all three models are able to train correctly without overfitting. They however achieve a close performance, therefore hinting at the fact that going for deep neural networks, is not necessarily better.
#
# In fact, we could obtain very similar results with less layers and smaller sizes.
#
# Note that this is a particular case, here, because MNIST is a very nice dataset and very hard to underfit or overfit. In the future, however, it would be a good practice to check different sizes for you deep neural network architecture and control whether you are underfitting, overfitting or fitting the data just right.
#
# As mentioned in the notebook 7 from W2, it would be also good practice to keep saves of your models during training times and eventually use the best model you have obtained after you have tried a few different hyperparameters (number of layers, number of neurons, learning rates, etc.).

# %%
plt.figure(figsize = (10, 7))
plt.plot(train_accs1, "r-", label = "Model 1 train acc.")
plt.plot(test_accs1, "b-", label = "Model 1 test acc.")
plt.plot(train_accs2, "r--", label = "Model 2 train acc.")
plt.plot(test_accs2, "b--", label = "Model 2 test acc.")
plt.plot(train_accs3, "r:", label = "Model 3 train acc.")
plt.plot(test_accs3, "b:", label = "Model 3 test acc.")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# ### What's next?
#
# In this notebook, we were able to perform image recognition using Deep Neural Networks and obtained a rather good test accuracy of 96% after training. While this appears as not too bad, this mainly has to do with MNIST being a nice dataset. In  practice, when it comes to processing images passed as inputs, the fully connected/Linear layers are not really the best choice, and they might rapidly struggle once the images become more sophisticated (higher resolution than 28x28, no longer greyscale but RGB, etc.).
#
# Next week, we will discuss the convolution operation, which is a different operation than the $ Wx + b $ one, which can be used as a layer in Neural Networks, and see why it is far superior when it comes to processing images.
