# %% [markdown]
# # 7. PyTorch Basics - Good practices in Deep Learning Projects
#
# ### About this notebook
#
# This notebook was used in the 50.039 Deep Learning course at the Singapore University of Technology and Design.
#
# **Author:** Matthieu DE MARI (matthieu_demari@sutd.edu.sg)
#
# **Version:** 1.0 (27/12/2022)
#
# **Requirements:**
# - Python 3 (tested on v3.9.6)
# - Matplotlib (tested on v3.5.1)
# - Numpy (tested on v1.22.1)
# - Time
# - Torch (tested on v1.13.0)
# - Torchmetrics (tested on v0.11.0)

# %% [markdown]
# ### Imports and CUDA

# %%
# Matplotlib
import matplotlib.pyplot as plt
from matplotlib import cm
# Numpy
import numpy as np
from numpy.random import default_rng
# OS
import os
# Pickle
import pickle
# Time
from time import time
# Torch
import torch
import torchvision
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Compose, Normalize
from torchvision.datasets import MNIST

# %%
# Use GPU if available, else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### The MNIST Dataset
#
# As in the previous notebook

# %%
# Define transform to convert images to tensors and normalize them
transform_data = Compose([ToTensor(),
                          Normalize((0.1307,), (0.3081,))])

# Load the data
batch_size = 256
train_dataset = MNIST(root='./mnist/', train = True, download = True, transform = transform_data)
test_dataset = MNIST(root='./mnist/', train = False, download = True, transform = transform_data)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)

# %% [markdown]
# ### Our deep neural network
#
# As in the previous notebook.
#
# However, we have stremalined the DeepNeuralNet class and its init method so that it can work with any number of elements in the list n_h (instead of just 3). The Sequential will then adjust automatically to produce any appropriate number of DenseReLU layers and finish with a single DenseSoftmax one.

# %%
class DenseReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        # Using ReLU operation as activation after
        return torch.relu(self.fc(x))

# %%
class DenseNoReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        return self.fc(x)

# %%
class DeepNeuralNet(torch.nn.Module):
    def __init__(self, n_x, n_h, n_y):
        super().__init__()
        # Define the correct number of Dense + ReLU layers based on n_h,
        # followed by one final Dense + Softmax layer
        values = [n_x] + n_h
        self.processing_layers = [DenseReLU(values[i], values[i + 1]) for i in range(len(values) - 1)]
        self.processing_layers += [DenseNoReLU(n_h[-1], n_y)]
        
        # Combine all layers
        # Important: note the * symbol before the list of layers in self.processing_layers
        # Not sure what it does? Check the *args and **kwargs concepts in Python.
        self.combined_layers = torch.nn.Sequential(*self.processing_layers)

    
    def forward(self, x):
        # Flatten images (transform them from 28x28 2D matrices to 784 1D vectors)
        x = x.view(x.size(0), -1)
        # Pass through all four layers
        out = self.combined_layers(x)
        return out

# %% [markdown]
# Let us try our Deep Neural Net class with more layers, e.g. n_h $ = [320, 160, 80, 40, 20] $.

# %%
# Initialize the model
model = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
# This will display a recap of the different layers
print(model.modules)
# Out:
# <bound method Module.modules of DeepNeuralNet(
#   (combined_layers): Sequential(
#     (0): DenseReLU(
#       (fc): Linear(in_features=784, out_features=320, bias=True)
#     )
#     (1): DenseReLU(
#       (fc): Linear(in_features=320, out_features=160, bias=True)
#     )
#     (2): DenseReLU(
#       (fc): Linear(in_features=160, out_features=80, bias=True)
#     )
#     (3): DenseReLU(
#       (fc): Linear(in_features=80, out_features=40, bias=True)
#     )
#     (4): DenseReLU(
#       (fc): Linear(in_features=40, out_features=20, bias=True)
#     )
#     (5): DenseNoReLU(
#       (fc): Linear(in_features=20, out_features=10, bias=True)
#     )
#   )
# )>

# %% [markdown]
# ### Number of layers/neurons vs overfitting tradeoff
#
# In the previous noteboo, we raised a fairly important question: **what is the appropriate number of layers to use and how many neurons should we use on each layer?**
#
# We established that there is no fixed rule for how many layers should be used in a deep neural network. Instead, the number of layers, as well as the number of neurons in each layer, should be chosen based on the complexity of the task and the amount of available data.
#
# In general, deep neural networks with many layers (hundreds or even thousands) can learn very complex patterns in data, but they also require a large amount of data and computational resources to train. If the network is too deep, it may also be prone to overfitting, which can hinder its generalization performance on unseen data.
#
# On the other hand, shallow networks with fewer layers may be easier to train and require less data, but they may not be able to learn as complex patterns and may not achieve as high performance on some tasks.
#
# Finding the optimal number of layers and the optimal architecture of a deep neural network is often a trade-off between model complexity, computational resources, and performance, and requires some experimentation and model selection.

# %% [markdown]
# ### Before we continue, reworking the trainer() fucntion to get performance curves
#
# We just add two lists keeping track of the train and test accuracies during training. Values will be appended to them during training. The entire code is then brought into a trainer() function for convenience.

# %%
def trainer(model, train_loader, test_loader):
    
    # History for train acc, test acc
    train_accs = []
    test_accs = []
    
    # Define optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr = 1e-2)

    # Training model
    num_epochs = 10
    for epoch in range(num_epochs):

        # Go trough all samples in train dataset
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            # Get from dataloader and send to device
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)

            # Compute loss
            loss = torch.nn.functional.cross_entropy(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Display
            if (i+1) % 25 == 0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Train Loss: {loss.item():.4f}')

        # Compute model train accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in train_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        train_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Accuracy: {train_accuracy:.4f}')
        train_accs.append(train_accuracy)
        
        # Compute model test accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in test_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        test_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {test_accuracy:.4f}')
        test_accs.append(test_accuracy)
        
    # Return
    return train_accs, test_accs

# %% [markdown]
# Let us now try to train three different models:
# - One model with 6 layers (n_h = [320, 160, 80, 40, 20]),
# - One model with three layers (n_h = [400, 200]),
# - And one model with three layers, but smaller ones (n_h = [40, 20]).

# %%
# Train a first model with 6 layers
model1 = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
train_accs1, test_accs1 = trainer(model1, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.6707
# Epoch [1/10], Step [50/235], Train Loss: 0.3275
# Epoch [1/10], Step [75/235], Train Loss: 0.2650
# Epoch [1/10], Step [100/235], Train Loss: 0.2095
# Epoch [1/10], Step [125/235], Train Loss: 0.2304
# Epoch [1/10], Step [150/235], Train Loss: 0.1933
# Epoch [1/10], Step [175/235], Train Loss: 0.2092
# Epoch [1/10], Step [200/235], Train Loss: 0.2030
# Epoch [1/10], Step [225/235], Train Loss: 0.1865
# Epoch [1/10], Train Accuracy: 0.9520
# Epoch [1/10], Test Accuracy: 0.9463
# Epoch [2/10], Step [25/235], Train Loss: 0.0955
# Epoch [2/10], Step [50/235], Train Loss: 0.1018
# Epoch [2/10], Step [75/235], Train Loss: 0.1199
# Epoch [2/10], Step [100/235], Train Loss: 0.1149
# Epoch [2/10], Step [125/235], Train Loss: 0.1288
# Epoch [2/10], Step [150/235], Train Loss: 0.0881
# Epoch [2/10], Step [175/235], Train Loss: 0.1690
# Epoch [2/10], Step [200/235], Train Loss: 0.1702
# Epoch [2/10], Step [225/235], Train Loss: 0.1325
# Epoch [2/10], Train Accuracy: 0.9663
# Epoch [2/10], Test Accuracy: 0.9592
# Epoch [3/10], Step [25/235], Train Loss: 0.0569
# Epoch [3/10], Step [50/235], Train Loss: 0.1376
# Epoch [3/10], Step [75/235], Train Loss: 0.0822
# Epoch [3/10], Step [100/235], Train Loss: 0.0878
# Epoch [3/10], Step [125/235], Train Loss: 0.1271
# Epoch [3/10], Step [150/235], Train Loss: 0.1234
# Epoch [3/10], Step [175/235], Train Loss: 0.1508
# Epoch [3/10], Step [200/235], Train Loss: 0.1132
# Epoch [3/10], Step [225/235], Train Loss: 0.1384
# Epoch [3/10], Train Accuracy: 0.9728
# Epoch [3/10], Test Accuracy: 0.9643
# Epoch [4/10], Step [25/235], Train Loss: 0.0895
# Epoch [4/10], Step [50/235], Train Loss: 0.1250
# Epoch [4/10], Step [75/235], Train Loss: 0.1309
# Epoch [4/10], Step [100/235], Train Loss: 0.0859
# Epoch [4/10], Step [125/235], Train Loss: 0.0493
# Epoch [4/10], Step [150/235], Train Loss: 0.1166
# Epoch [4/10], Step [175/235], Train Loss: 0.1185
# Epoch [4/10], Step [200/235], Train Loss: 0.0771
# Epoch [4/10], Step [225/235], Train Loss: 0.0505
# Epoch [4/10], Train Accuracy: 0.9802
# Epoch [4/10], Test Accuracy: 0.9709
# Epoch [5/10], Step [25/235], Train Loss: 0.1299
# Epoch [5/10], Step [50/235], Train Loss: 0.0883
# Epoch [5/10], Step [75/235], Train Loss: 0.1977
# Epoch [5/10], Step [100/235], Train Loss: 0.0776
# Epoch [5/10], Step [125/235], Train Loss: 0.1021
# Epoch [5/10], Step [150/235], Train Loss: 0.0933
# Epoch [5/10], Step [175/235], Train Loss: 0.0771
# Epoch [5/10], Step [200/235], Train Loss: 0.1185
# Epoch [5/10], Step [225/235], Train Loss: 0.0539
# Epoch [5/10], Train Accuracy: 0.9758
# Epoch [5/10], Test Accuracy: 0.9645
# Epoch [6/10], Step [25/235], Train Loss: 0.0651
# Epoch [6/10], Step [50/235], Train Loss: 0.0961
# Epoch [6/10], Step [75/235], Train Loss: 0.1030
# Epoch [6/10], Step [100/235], Train Loss: 0.0298
# Epoch [6/10], Step [125/235], Train Loss: 0.0930
# Epoch [6/10], Step [150/235], Train Loss: 0.0931
# Epoch [6/10], Step [175/235], Train Loss: 0.1054
# Epoch [6/10], Step [200/235], Train Loss: 0.1365
# Epoch [6/10], Step [225/235], Train Loss: 0.0897
# Epoch [6/10], Train Accuracy: 0.9788
# Epoch [6/10], Test Accuracy: 0.9685
# Epoch [7/10], Step [25/235], Train Loss: 0.1500
# Epoch [7/10], Step [50/235], Train Loss: 0.0679
# Epoch [7/10], Step [75/235], Train Loss: 0.0573
# Epoch [7/10], Step [100/235], Train Loss: 0.0568
# Epoch [7/10], Step [125/235], Train Loss: 0.0787
# Epoch [7/10], Step [150/235], Train Loss: 0.0617
# Epoch [7/10], Step [175/235], Train Loss: 0.0761
# Epoch [7/10], Step [200/235], Train Loss: 0.0563
# Epoch [7/10], Step [225/235], Train Loss: 0.1592
# Epoch [7/10], Train Accuracy: 0.9799
# Epoch [7/10], Test Accuracy: 0.9729
# Epoch [8/10], Step [25/235], Train Loss: 0.0418
# Epoch [8/10], Step [50/235], Train Loss: 0.1341
# Epoch [8/10], Step [75/235], Train Loss: 0.0432
# Epoch [8/10], Step [100/235], Train Loss: 0.1041
# Epoch [8/10], Step [125/235], Train Loss: 0.0750
# Epoch [8/10], Step [150/235], Train Loss: 0.0635
# Epoch [8/10], Step [175/235], Train Loss: 0.0691
# Epoch [8/10], Step [200/235], Train Loss: 0.0498
# Epoch [8/10], Step [225/235], Train Loss: 0.1333
# Epoch [8/10], Train Accuracy: 0.9847
# Epoch [8/10], Test Accuracy: 0.9716
# Epoch [9/10], Step [25/235], Train Loss: 0.0950
# Epoch [9/10], Step [50/235], Train Loss: 0.0779
# Epoch [9/10], Step [75/235], Train Loss: 0.0608
# Epoch [9/10], Step [100/235], Train Loss: 0.0433
# Epoch [9/10], Step [125/235], Train Loss: 0.0615
# Epoch [9/10], Step [150/235], Train Loss: 0.0857
# Epoch [9/10], Step [175/235], Train Loss: 0.0587
# Epoch [9/10], Step [200/235], Train Loss: 0.1220
# Epoch [9/10], Step [225/235], Train Loss: 0.0594
# Epoch [9/10], Train Accuracy: 0.9886
# Epoch [9/10], Test Accuracy: 0.9766
# Epoch [10/10], Step [25/235], Train Loss: 0.0373
# Epoch [10/10], Step [50/235], Train Loss: 0.0478
# Epoch [10/10], Step [75/235], Train Loss: 0.0153
# Epoch [10/10], Step [100/235], Train Loss: 0.0408
# Epoch [10/10], Step [125/235], Train Loss: 0.0271
# Epoch [10/10], Step [150/235], Train Loss: 0.0657
# Epoch [10/10], Step [175/235], Train Loss: 0.0471
# Epoch [10/10], Step [200/235], Train Loss: 0.0271
# Epoch [10/10], Step [225/235], Train Loss: 0.0999
# Epoch [10/10], Train Accuracy: 0.9890
# Epoch [10/10], Test Accuracy: 0.9748

# %%
# Train a second model with 3 layers
model2 = DeepNeuralNet(n_x = 784, n_h = [400, 200], n_y = 10).to(device)
train_accs2, test_accs2 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.4096
# Epoch [1/10], Step [50/235], Train Loss: 0.3545
# Epoch [1/10], Step [75/235], Train Loss: 0.3360
# Epoch [1/10], Step [100/235], Train Loss: 0.1382
# Epoch [1/10], Step [125/235], Train Loss: 0.2027
# Epoch [1/10], Step [150/235], Train Loss: 0.1244
# Epoch [1/10], Step [175/235], Train Loss: 0.1922
# Epoch [1/10], Step [200/235], Train Loss: 0.1143
# Epoch [1/10], Step [225/235], Train Loss: 0.1723
# Epoch [1/10], Train Accuracy: 0.9559
# Epoch [1/10], Test Accuracy: 0.9519
# Epoch [2/10], Step [25/235], Train Loss: 0.1031
# Epoch [2/10], Step [50/235], Train Loss: 0.1567
# Epoch [2/10], Step [75/235], Train Loss: 0.1269
# Epoch [2/10], Step [100/235], Train Loss: 0.1290
# Epoch [2/10], Step [125/235], Train Loss: 0.1372
# Epoch [2/10], Step [150/235], Train Loss: 0.0941
# Epoch [2/10], Step [175/235], Train Loss: 0.1220
# Epoch [2/10], Step [200/235], Train Loss: 0.0914
# Epoch [2/10], Step [225/235], Train Loss: 0.0969
# Epoch [2/10], Train Accuracy: 0.9632
# Epoch [2/10], Test Accuracy: 0.9603
# Epoch [3/10], Step [25/235], Train Loss: 0.0986
# Epoch [3/10], Step [50/235], Train Loss: 0.1433
# Epoch [3/10], Step [75/235], Train Loss: 0.1652
# Epoch [3/10], Step [100/235], Train Loss: 0.0833
# Epoch [3/10], Step [125/235], Train Loss: 0.1073
# Epoch [3/10], Step [150/235], Train Loss: 0.1415
# Epoch [3/10], Step [175/235], Train Loss: 0.1622
# Epoch [3/10], Step [200/235], Train Loss: 0.1163
# Epoch [3/10], Step [225/235], Train Loss: 0.1703
# Epoch [3/10], Train Accuracy: 0.9732
# Epoch [3/10], Test Accuracy: 0.9642
# Epoch [4/10], Step [25/235], Train Loss: 0.2263
# Epoch [4/10], Step [50/235], Train Loss: 0.0982
# Epoch [4/10], Step [75/235], Train Loss: 0.0283
# Epoch [4/10], Step [100/235], Train Loss: 0.0891
# Epoch [4/10], Step [125/235], Train Loss: 0.0916
# Epoch [4/10], Step [150/235], Train Loss: 0.0929
# Epoch [4/10], Step [175/235], Train Loss: 0.0948
# Epoch [4/10], Step [200/235], Train Loss: 0.1420
# Epoch [4/10], Step [225/235], Train Loss: 0.0769
# Epoch [4/10], Train Accuracy: 0.9682
# Epoch [4/10], Test Accuracy: 0.9562
# Epoch [5/10], Step [25/235], Train Loss: 0.1091
# Epoch [5/10], Step [50/235], Train Loss: 0.0258
# Epoch [5/10], Step [75/235], Train Loss: 0.1369
# Epoch [5/10], Step [100/235], Train Loss: 0.0689
# Epoch [5/10], Step [125/235], Train Loss: 0.1215
# Epoch [5/10], Step [150/235], Train Loss: 0.0471
# Epoch [5/10], Step [175/235], Train Loss: 0.0454
# Epoch [5/10], Step [200/235], Train Loss: 0.0836
# Epoch [5/10], Step [225/235], Train Loss: 0.1226
# Epoch [5/10], Train Accuracy: 0.9741
# Epoch [5/10], Test Accuracy: 0.9626
# Epoch [6/10], Step [25/235], Train Loss: 0.1743
# Epoch [6/10], Step [50/235], Train Loss: 0.0872
# Epoch [6/10], Step [75/235], Train Loss: 0.0562
# Epoch [6/10], Step [100/235], Train Loss: 0.1155
# Epoch [6/10], Step [125/235], Train Loss: 0.0628
# Epoch [6/10], Step [150/235], Train Loss: 0.0729
# Epoch [6/10], Step [175/235], Train Loss: 0.0556
# Epoch [6/10], Step [200/235], Train Loss: 0.1394
# Epoch [6/10], Step [225/235], Train Loss: 0.0647
# Epoch [6/10], Train Accuracy: 0.9735
# Epoch [6/10], Test Accuracy: 0.9642
# Epoch [7/10], Step [25/235], Train Loss: 0.1533
# Epoch [7/10], Step [50/235], Train Loss: 0.0381
# Epoch [7/10], Step [75/235], Train Loss: 0.0413
# Epoch [7/10], Step [100/235], Train Loss: 0.1027
# Epoch [7/10], Step [125/235], Train Loss: 0.1184
# Epoch [7/10], Step [150/235], Train Loss: 0.0631
# Epoch [7/10], Step [175/235], Train Loss: 0.1187
# Epoch [7/10], Step [200/235], Train Loss: 0.0704
# Epoch [7/10], Step [225/235], Train Loss: 0.0943
# Epoch [7/10], Train Accuracy: 0.9788
# Epoch [7/10], Test Accuracy: 0.9675
# Epoch [8/10], Step [25/235], Train Loss: 0.0993
# Epoch [8/10], Step [50/235], Train Loss: 0.0281
# Epoch [8/10], Step [75/235], Train Loss: 0.0504
# Epoch [8/10], Step [100/235], Train Loss: 0.1269
# Epoch [8/10], Step [125/235], Train Loss: 0.0405
# Epoch [8/10], Step [150/235], Train Loss: 0.0433
# Epoch [8/10], Step [175/235], Train Loss: 0.0676
# Epoch [8/10], Step [200/235], Train Loss: 0.1057
# Epoch [8/10], Step [225/235], Train Loss: 0.0865
# Epoch [8/10], Train Accuracy: 0.9807
# Epoch [8/10], Test Accuracy: 0.9689
# Epoch [9/10], Step [25/235], Train Loss: 0.1790
# Epoch [9/10], Step [50/235], Train Loss: 0.0655
# Epoch [9/10], Step [75/235], Train Loss: 0.1543
# Epoch [9/10], Step [100/235], Train Loss: 0.1048
# Epoch [9/10], Step [125/235], Train Loss: 0.0268
# Epoch [9/10], Step [150/235], Train Loss: 0.0542
# Epoch [9/10], Step [175/235], Train Loss: 0.0955
# Epoch [9/10], Step [200/235], Train Loss: 0.0633
# Epoch [9/10], Step [225/235], Train Loss: 0.1402
# Epoch [9/10], Train Accuracy: 0.9822
# Epoch [9/10], Test Accuracy: 0.9708
# Epoch [10/10], Step [25/235], Train Loss: 0.0815
# Epoch [10/10], Step [50/235], Train Loss: 0.0720
# Epoch [10/10], Step [75/235], Train Loss: 0.0864
# Epoch [10/10], Step [100/235], Train Loss: 0.0504
# Epoch [10/10], Step [125/235], Train Loss: 0.0837
# Epoch [10/10], Step [150/235], Train Loss: 0.0614
# Epoch [10/10], Step [175/235], Train Loss: 0.0890
# Epoch [10/10], Step [200/235], Train Loss: 0.0626
# Epoch [10/10], Step [225/235], Train Loss: 0.0119
# Epoch [10/10], Train Accuracy: 0.9838
# Epoch [10/10], Test Accuracy: 0.9675

# %%
# Train a second model with 3 layers
model3 = DeepNeuralNet(n_x = 784, n_h = [40, 20], n_y = 10).to(device)
train_accs3, test_accs3 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.1858
# Epoch [1/10], Step [50/235], Train Loss: 0.1138
# Epoch [1/10], Step [75/235], Train Loss: 0.0622
# Epoch [1/10], Step [100/235], Train Loss: 0.0158
# Epoch [1/10], Step [125/235], Train Loss: 0.0759
# Epoch [1/10], Step [150/235], Train Loss: 0.1404
# Epoch [1/10], Step [175/235], Train Loss: 0.0901
# Epoch [1/10], Step [200/235], Train Loss: 0.1200
# Epoch [1/10], Step [225/235], Train Loss: 0.0616
# Epoch [1/10], Train Accuracy: 0.9821
# Epoch [1/10], Test Accuracy: 0.9667
# Epoch [2/10], Step [25/235], Train Loss: 0.0529
# Epoch [2/10], Step [50/235], Train Loss: 0.0155
# Epoch [2/10], Step [75/235], Train Loss: 0.0295
# Epoch [2/10], Step [100/235], Train Loss: 0.0882
# Epoch [2/10], Step [125/235], Train Loss: 0.1021
# Epoch [2/10], Step [150/235], Train Loss: 0.1799
# Epoch [2/10], Step [175/235], Train Loss: 0.1662
# Epoch [2/10], Step [200/235], Train Loss: 0.1325
# Epoch [2/10], Step [225/235], Train Loss: 0.0483
# Epoch [2/10], Train Accuracy: 0.9817
# Epoch [2/10], Test Accuracy: 0.9687
# Epoch [3/10], Step [25/235], Train Loss: 0.0848
# Epoch [3/10], Step [50/235], Train Loss: 0.0751
# Epoch [3/10], Step [75/235], Train Loss: 0.0547
# Epoch [3/10], Step [100/235], Train Loss: 0.0567
# Epoch [3/10], Step [125/235], Train Loss: 0.0468
# Epoch [3/10], Step [150/235], Train Loss: 0.0882
# Epoch [3/10], Step [175/235], Train Loss: 0.1422
# Epoch [3/10], Step [200/235], Train Loss: 0.0473
# Epoch [3/10], Step [225/235], Train Loss: 0.0268
# Epoch [3/10], Train Accuracy: 0.9824
# Epoch [3/10], Test Accuracy: 0.9687
# Epoch [4/10], Step [25/235], Train Loss: 0.0498
# Epoch [4/10], Step [50/235], Train Loss: 0.0855
# Epoch [4/10], Step [75/235], Train Loss: 0.2039
# Epoch [4/10], Step [100/235], Train Loss: 0.0170
# Epoch [4/10], Step [125/235], Train Loss: 0.0675
# Epoch [4/10], Step [150/235], Train Loss: 0.0507
# Epoch [4/10], Step [175/235], Train Loss: 0.0876
# Epoch [4/10], Step [200/235], Train Loss: 0.0435
# Epoch [4/10], Step [225/235], Train Loss: 0.0520
# Epoch [4/10], Train Accuracy: 0.9852
# Epoch [4/10], Test Accuracy: 0.9706
# Epoch [5/10], Step [25/235], Train Loss: 0.0196
# Epoch [5/10], Step [50/235], Train Loss: 0.0313
# Epoch [5/10], Step [75/235], Train Loss: 0.0406
# Epoch [5/10], Step [100/235], Train Loss: 0.0438
# Epoch [5/10], Step [125/235], Train Loss: 0.0165
# Epoch [5/10], Step [150/235], Train Loss: 0.0662
# Epoch [5/10], Step [175/235], Train Loss: 0.1122
# Epoch [5/10], Step [200/235], Train Loss: 0.0749
# Epoch [5/10], Step [225/235], Train Loss: 0.0087
# Epoch [5/10], Train Accuracy: 0.9864
# Epoch [5/10], Test Accuracy: 0.9729
# Epoch [6/10], Step [25/235], Train Loss: 0.0359
# Epoch [6/10], Step [50/235], Train Loss: 0.0975
# Epoch [6/10], Step [75/235], Train Loss: 0.0490
# Epoch [6/10], Step [100/235], Train Loss: 0.0450
# Epoch [6/10], Step [125/235], Train Loss: 0.0813
# Epoch [6/10], Step [150/235], Train Loss: 0.0640
# Epoch [6/10], Step [175/235], Train Loss: 0.0667
# Epoch [6/10], Step [200/235], Train Loss: 0.0228
# Epoch [6/10], Step [225/235], Train Loss: 0.0792
# Epoch [6/10], Train Accuracy: 0.9866
# Epoch [6/10], Test Accuracy: 0.9716
# Epoch [7/10], Step [25/235], Train Loss: 0.0599
# Epoch [7/10], Step [50/235], Train Loss: 0.0176
# Epoch [7/10], Step [75/235], Train Loss: 0.0490
# Epoch [7/10], Step [100/235], Train Loss: 0.0908
# Epoch [7/10], Step [125/235], Train Loss: 0.0806
# Epoch [7/10], Step [150/235], Train Loss: 0.0439
# Epoch [7/10], Step [175/235], Train Loss: 0.0288
# Epoch [7/10], Step [200/235], Train Loss: 0.0533
# Epoch [7/10], Step [225/235], Train Loss: 0.0774
# Epoch [7/10], Train Accuracy: 0.9861
# Epoch [7/10], Test Accuracy: 0.9723
# Epoch [8/10], Step [25/235], Train Loss: 0.0519
# Epoch [8/10], Step [50/235], Train Loss: 0.0223
# Epoch [8/10], Step [75/235], Train Loss: 0.0177
# Epoch [8/10], Step [100/235], Train Loss: 0.0329
# Epoch [8/10], Step [125/235], Train Loss: 0.0609
# Epoch [8/10], Step [150/235], Train Loss: 0.1136
# Epoch [8/10], Step [175/235], Train Loss: 0.1362
# Epoch [8/10], Step [200/235], Train Loss: 0.0375
# Epoch [8/10], Step [225/235], Train Loss: 0.0835
# Epoch [8/10], Train Accuracy: 0.9868
# Epoch [8/10], Test Accuracy: 0.9714
# Epoch [9/10], Step [25/235], Train Loss: 0.0635
# Epoch [9/10], Step [50/235], Train Loss: 0.0578
# Epoch [9/10], Step [75/235], Train Loss: 0.1426
# Epoch [9/10], Step [100/235], Train Loss: 0.1612
# Epoch [9/10], Step [125/235], Train Loss: 0.0676
# Epoch [9/10], Step [150/235], Train Loss: 0.0459
# Epoch [9/10], Step [175/235], Train Loss: 0.0249
# Epoch [9/10], Step [200/235], Train Loss: 0.0225
# Epoch [9/10], Step [225/235], Train Loss: 0.0502
# Epoch [9/10], Train Accuracy: 0.9799
# Epoch [9/10], Test Accuracy: 0.9696
# Epoch [10/10], Step [25/235], Train Loss: 0.0787
# Epoch [10/10], Step [50/235], Train Loss: 0.0363
# Epoch [10/10], Step [75/235], Train Loss: 0.0112
# Epoch [10/10], Step [100/235], Train Loss: 0.0843
# Epoch [10/10], Step [125/235], Train Loss: 0.0787
# Epoch [10/10], Step [150/235], Train Loss: 0.1060
# Epoch [10/10], Step [175/235], Train Loss: 0.0747
# Epoch [10/10], Step [200/235], Train Loss: 0.0259
# Epoch [10/10], Step [225/235], Train Loss: 0.0412
# Epoch [10/10], Train Accuracy: 0.9895
# Epoch [10/10], Test Accuracy: 0.9730

# %% [markdown]
# The first thing we can observe is that the training time seems to scale with the number of trainable parameters (total number of neurons in all layers combined togather).
#
# Looking at the performance curves below, we can see that all three models are able to train correctly without overfitting. They however achieve a close performance, therefore hinting at the fact that going for deep neural networks, is not necessarily better.
#
# In fact, we could obtain very similar results with less layers and smaller sizes.
#
# Note that this is a particular case, here, because MNIST is a very nice dataset and very hard to underfit or overfit. In the future, however, it would be a good practice to check different sizes for you deep neural network architecture and control whether you are underfitting, overfitting or fitting the data just right.
#
# As mentioned in the notebook 7 from W2, it would be also good practice to keep saves of your models during training times and eventually use the best model you have obtained after you have tried a few different hyperparameters (number of layers, number of neurons, learning rates, etc.).

# %%
plt.figure(figsize = (10, 7))
plt.plot(train_accs1, "r-", label = "Model 1 train acc.")
plt.plot(test_accs1, "b-", label = "Model 1 test acc.")
plt.plot(train_accs2, "r--", label = "Model 2 train acc.")
plt.plot(test_accs2, "b--", label = "Model 2 test acc.")
plt.plot(train_accs3, "r:", label = "Model 3 train acc.")
plt.plot(test_accs3, "b:", label = "Model 3 test acc.")
plt.legend(loc = "best")
plt.show()

# %% [markdown]
# ### What's next?
#
# In this notebook, we were able to perform image recognition using Deep Neural Networks and obtained a rather good test accuracy of 96% after training. While this appears as not too bad, this mainly has to do with MNIST being a nice dataset. In  practice, when it comes to processing images passed as inputs, the fully connected/Linear layers are not really the best choice, and they might rapidly struggle once the images become more sophisticated (higher resolution than 28x28, no longer greyscale but RGB, etc.).
#
# Next week, we will discuss the convolution operation, which is a different operation than the $ Wx + b $ one, which can be used as a layer in Neural Networks, and see why it is far superior when it comes to processing images.
