# %% [markdown]
# # 8. PyTorch Basics - Good practices in Deep Learning Projects
#
# ### About this notebook
#
# This notebook was used in the 50.039 Deep Learning course at the Singapore University of Technology and Design.
#
# **Author:** Matthieu DE MARI (matthieu_demari@sutd.edu.sg)
#
# **Version:** 1.2 (22/06/2023)
#
# **Requirements:**
# - Python 3 (tested on v3.11.4)
# - Matplotlib (tested on v3.7.1)
# - Numpy (tested on v1.24.3)
# - Torch (tested on v2.0.1+cu118)

# %% [markdown]
# ### Imports and CUDA

# %%
# Matplotlib
import matplotlib.pyplot as plt
# Numpy
import numpy as np
# Torch
import torch
import torchvision
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Compose, Normalize
from torchvision.datasets import MNIST

# %%
# Use GPU if available, else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### The MNIST Dataset
#
# As in the previous notebook

# %%
# Define transform to convert images to tensors and normalize them
transform_data = Compose([ToTensor(),
                          Normalize((0.1307,), (0.3081,))])

# Load the data
batch_size = 256
train_dataset = MNIST(root='./mnist/', train = True, download = True, transform = transform_data)
test_dataset = MNIST(root='./mnist/', train = False, download = True, transform = transform_data)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)

# %% [markdown]
# ### Our deep neural network
#
# As in the previous notebook.
#
# However, we have stremalined the DeepNeuralNet class and its init method so that it can work with any number of elements in the list n_h (instead of just 3). The Sequential will then adjust automatically to produce any appropriate number of DenseReLU layers and finish with a single DenseSoftmax one.

# %%
class DenseReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        # Using ReLU operation as activation after
        return torch.relu(self.fc(x))

# %%
class DenseNoReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        return self.fc(x)

# %%
class DeepNeuralNet(torch.nn.Module):
    def __init__(self, n_x, n_h, n_y):
        super().__init__()
        # Define the correct number of Dense + ReLU layers based on n_h,
        # followed by one final Dense + Softmax layer
        values = [n_x] + n_h
        self.processing_layers = [DenseReLU(values[i], values[i + 1]) for i in range(len(values) - 1)]
        self.processing_layers += [DenseNoReLU(n_h[-1], n_y)]
        
        # Combine all layers
        # Important: note the * symbol before the list of layers in self.processing_layers
        # Not sure what it does? Check the *args and **kwargs concepts in Python.
        self.combined_layers = torch.nn.Sequential(*self.processing_layers)

    
    def forward(self, x):
        # Flatten images (transform them from 28x28 2D matrices to 784 1D vectors)
        x = x.view(x.size(0), -1)
        # Pass through all four layers
        out = self.combined_layers(x)
        return out

# %% [markdown]
# Let us try our Deep Neural Net class with more layers, e.g. n_h $ = [320, 160, 80, 40, 20] $.

# %%
# Initialize the model
model = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
# Set model in train mode!
model.train()
# This will display a recap of the different layers
print(model.modules)
# Out:
# <bound method Module.modules of DeepNeuralNet(
#   (combined_layers): Sequential(
#     (0): DenseReLU(
#       (fc): Linear(in_features=784, out_features=320, bias=True)
#     )
#     (1): DenseReLU(
#       (fc): Linear(in_features=320, out_features=160, bias=True)
#     )
#     (2): DenseReLU(
#       (fc): Linear(in_features=160, out_features=80, bias=True)
#     )
#     (3): DenseReLU(
#       (fc): Linear(in_features=80, out_features=40, bias=True)
#     )
#     (4): DenseReLU(
#       (fc): Linear(in_features=40, out_features=20, bias=True)
#     )
#     (5): DenseNoReLU(
#       (fc): Linear(in_features=20, out_features=10, bias=True)
#     )
#   )
# )>

# %% [markdown]
# ### Number of layers/neurons vs overfitting tradeoff
#
# In the previous noteboo, we raised a fairly important question: **what is the appropriate number of layers to use and how many neurons should we use on each layer?**
#
# We established that there is no fixed rule for how many layers should be used in a deep neural network. Instead, the number of layers, as well as the number of neurons in each layer, should be chosen based on the complexity of the task and the amount of available data.
#
# In general, deep neural networks with many layers (hundreds or even thousands) can learn very complex patterns in data, but they also require a large amount of data and computational resources to train. If the network is too deep, it may also be prone to overfitting, which can hinder its generalization performance on unseen data.
#
# On the other hand, shallow networks with fewer layers may be easier to train and require less data, but they may not be able to learn as complex patterns and may not achieve as high performance on some tasks.
#
# Finding the optimal number of layers and the optimal architecture of a deep neural network is often a trade-off between model complexity, computational resources, and performance, and requires some experimentation and model selection.

# %% [markdown]
# ### Before we continue, reworking the trainer() function to get performance curves
#
# We just add two lists keeping track of the train and test accuracies during training. Values will be appended to them during training. The entire code is then brought into a trainer() function for convenience.

# %%
def trainer(model, train_loader, test_loader):
    
    # History for train acc, test acc
    train_accs = []
    test_accs = []
    
    # Define optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr = 1e-2)

    # Training model
    num_epochs = 10
    for epoch in range(num_epochs):

        # Go trough all samples in train dataset
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            # Get from dataloader and send to device
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)

            # Compute loss
            loss = torch.nn.functional.cross_entropy(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Display
            if (i+1) % 25 == 0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Train Loss: {loss.item():.4f}')

        # Compute model train accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in train_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        train_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Accuracy: {train_accuracy:.4f}')
        train_accs.append(train_accuracy)
        
        # Compute model test accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in test_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        test_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {test_accuracy:.4f}')
        test_accs.append(test_accuracy)
        
    # Return
    return train_accs, test_accs

# %% [markdown]
# Let us now try to train three different models:
# - One model with 6 layers (n_h = [320, 160, 80, 40, 20]),
# - One model with three layers (n_h = [400, 200]),
# - And one model with three layers, but smaller ones (n_h = [40, 20]).

# %%
# Train a first model with 6 layers
model1 = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
train_accs1, test_accs1 = trainer(model1, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.7942
# Epoch [1/10], Step [50/235], Train Loss: 0.4507
# Epoch [1/10], Step [75/235], Train Loss: 0.1859
# Epoch [1/10], Step [100/235], Train Loss: 0.2279
# Epoch [1/10], Step [125/235], Train Loss: 0.2024
# Epoch [1/10], Step [150/235], Train Loss: 0.1556
# Epoch [1/10], Step [175/235], Train Loss: 0.2254
# Epoch [1/10], Step [200/235], Train Loss: 0.1540
# Epoch [1/10], Step [225/235], Train Loss: 0.2099
# Epoch [1/10], Train Accuracy: 0.9595
# Epoch [1/10], Test Accuracy: 0.9590
# Epoch [2/10], Step [25/235], Train Loss: 0.1257
# Epoch [2/10], Step [50/235], Train Loss: 0.0827
# Epoch [2/10], Step [75/235], Train Loss: 0.0914
# Epoch [2/10], Step [100/235], Train Loss: 0.1228
# Epoch [2/10], Step [125/235], Train Loss: 0.1821
# Epoch [2/10], Step [150/235], Train Loss: 0.1355
# Epoch [2/10], Step [175/235], Train Loss: 0.1190
# Epoch [2/10], Step [200/235], Train Loss: 0.0748
# Epoch [2/10], Step [225/235], Train Loss: 0.1154
# Epoch [2/10], Train Accuracy: 0.9689
# Epoch [2/10], Test Accuracy: 0.9606
# Epoch [3/10], Step [25/235], Train Loss: 0.0967
# Epoch [3/10], Step [50/235], Train Loss: 0.1580
# Epoch [3/10], Step [75/235], Train Loss: 0.1058
# Epoch [3/10], Step [100/235], Train Loss: 0.1717
# Epoch [3/10], Step [125/235], Train Loss: 0.1609
# Epoch [3/10], Step [150/235], Train Loss: 0.1031
# Epoch [3/10], Step [175/235], Train Loss: 0.1056
# Epoch [3/10], Step [200/235], Train Loss: 0.1607
# Epoch [3/10], Step [225/235], Train Loss: 0.1063
# Epoch [3/10], Train Accuracy: 0.9762
# Epoch [3/10], Test Accuracy: 0.9691
# Epoch [4/10], Step [25/235], Train Loss: 0.0700
# Epoch [4/10], Step [50/235], Train Loss: 0.1971
# Epoch [4/10], Step [75/235], Train Loss: 0.0867
# Epoch [4/10], Step [100/235], Train Loss: 0.0633
# Epoch [4/10], Step [125/235], Train Loss: 0.0413
# Epoch [4/10], Step [150/235], Train Loss: 0.1054
# Epoch [4/10], Step [175/235], Train Loss: 0.0962
# Epoch [4/10], Step [200/235], Train Loss: 0.0905
# Epoch [4/10], Step [225/235], Train Loss: 0.0130
# Epoch [4/10], Train Accuracy: 0.9776
# Epoch [4/10], Test Accuracy: 0.9689
# Epoch [5/10], Step [25/235], Train Loss: 0.0823
# Epoch [5/10], Step [50/235], Train Loss: 0.0839
# Epoch [5/10], Step [75/235], Train Loss: 0.0793
# Epoch [5/10], Step [100/235], Train Loss: 0.0644
# Epoch [5/10], Step [125/235], Train Loss: 0.0690
# Epoch [5/10], Step [150/235], Train Loss: 0.0453
# Epoch [5/10], Step [175/235], Train Loss: 0.1449
# Epoch [5/10], Step [200/235], Train Loss: 0.0869
# Epoch [5/10], Step [225/235], Train Loss: 0.1303
# Epoch [5/10], Train Accuracy: 0.9809
# Epoch [5/10], Test Accuracy: 0.9710
# Epoch [6/10], Step [25/235], Train Loss: 0.0098
# Epoch [6/10], Step [50/235], Train Loss: 0.0933
# Epoch [6/10], Step [75/235], Train Loss: 0.0487
# Epoch [6/10], Step [100/235], Train Loss: 0.0629
# Epoch [6/10], Step [125/235], Train Loss: 0.0423
# Epoch [6/10], Step [150/235], Train Loss: 0.0567
# Epoch [6/10], Step [175/235], Train Loss: 0.1569
# Epoch [6/10], Step [200/235], Train Loss: 0.1435
# Epoch [6/10], Step [225/235], Train Loss: 0.1102
# Epoch [6/10], Train Accuracy: 0.9840
# Epoch [6/10], Test Accuracy: 0.9716
# Epoch [7/10], Step [25/235], Train Loss: 0.0317
# Epoch [7/10], Step [50/235], Train Loss: 0.1055
# Epoch [7/10], Step [75/235], Train Loss: 0.0789
# Epoch [7/10], Step [100/235], Train Loss: 0.0501
# Epoch [7/10], Step [125/235], Train Loss: 0.0796
# Epoch [7/10], Step [150/235], Train Loss: 0.1142
# Epoch [7/10], Step [175/235], Train Loss: 0.0488
# Epoch [7/10], Step [200/235], Train Loss: 0.0362
# Epoch [7/10], Step [225/235], Train Loss: 0.0267
# Epoch [7/10], Train Accuracy: 0.9850
# Epoch [7/10], Test Accuracy: 0.9739
# Epoch [8/10], Step [25/235], Train Loss: 0.0855
# Epoch [8/10], Step [50/235], Train Loss: 0.0601
# Epoch [8/10], Step [75/235], Train Loss: 0.0391
# Epoch [8/10], Step [100/235], Train Loss: 0.0560
# Epoch [8/10], Step [125/235], Train Loss: 0.0302
# Epoch [8/10], Step [150/235], Train Loss: 0.0932
# Epoch [8/10], Step [175/235], Train Loss: 0.1089
# Epoch [8/10], Step [200/235], Train Loss: 0.0352
# Epoch [8/10], Step [225/235], Train Loss: 0.0753
# Epoch [8/10], Train Accuracy: 0.9871
# Epoch [8/10], Test Accuracy: 0.9736
# Epoch [9/10], Step [25/235], Train Loss: 0.0621
# Epoch [9/10], Step [50/235], Train Loss: 0.0720
# Epoch [9/10], Step [75/235], Train Loss: 0.0554
# Epoch [9/10], Step [100/235], Train Loss: 0.1019
# Epoch [9/10], Step [125/235], Train Loss: 0.0690
# Epoch [9/10], Step [150/235], Train Loss: 0.0983
# Epoch [9/10], Step [175/235], Train Loss: 0.1256
# Epoch [9/10], Step [200/235], Train Loss: 0.0481
# Epoch [9/10], Step [225/235], Train Loss: 0.1227
# Epoch [9/10], Train Accuracy: 0.9842
# Epoch [9/10], Test Accuracy: 0.9729
# Epoch [10/10], Step [25/235], Train Loss: 0.0654
# Epoch [10/10], Step [50/235], Train Loss: 0.0898
# Epoch [10/10], Step [75/235], Train Loss: 0.0851
# Epoch [10/10], Step [100/235], Train Loss: 0.0823
# Epoch [10/10], Step [125/235], Train Loss: 0.0507
# Epoch [10/10], Step [150/235], Train Loss: 0.0184
# Epoch [10/10], Step [175/235], Train Loss: 0.0397
# Epoch [10/10], Step [200/235], Train Loss: 0.0289
# Epoch [10/10], Step [225/235], Train Loss: 0.0283
# Epoch [10/10], Train Accuracy: 0.9905
# Epoch [10/10], Test Accuracy: 0.9764

# %%
# Train a second model with 3 layers
model2 = DeepNeuralNet(n_x = 784, n_h = [400, 200], n_y = 10).to(device)
train_accs2, test_accs2 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.3888
# Epoch [1/10], Step [50/235], Train Loss: 0.2181
# Epoch [1/10], Step [75/235], Train Loss: 0.2402
# Epoch [1/10], Step [100/235], Train Loss: 0.1698
# Epoch [1/10], Step [125/235], Train Loss: 0.1128
# Epoch [1/10], Step [150/235], Train Loss: 0.1301
# Epoch [1/10], Step [175/235], Train Loss: 0.1369
# Epoch [1/10], Step [200/235], Train Loss: 0.1356
# Epoch [1/10], Step [225/235], Train Loss: 0.1390
# Epoch [1/10], Train Accuracy: 0.9572
# Epoch [1/10], Test Accuracy: 0.9535
# Epoch [2/10], Step [25/235], Train Loss: 0.1014
# Epoch [2/10], Step [50/235], Train Loss: 0.1238
# Epoch [2/10], Step [75/235], Train Loss: 0.1482
# Epoch [2/10], Step [100/235], Train Loss: 0.0729
# Epoch [2/10], Step [125/235], Train Loss: 0.1203
# Epoch [2/10], Step [150/235], Train Loss: 0.1624
# Epoch [2/10], Step [175/235], Train Loss: 0.0706
# Epoch [2/10], Step [200/235], Train Loss: 0.0909
# Epoch [2/10], Step [225/235], Train Loss: 0.1669
# Epoch [2/10], Train Accuracy: 0.9716
# Epoch [2/10], Test Accuracy: 0.9642
# Epoch [3/10], Step [25/235], Train Loss: 0.1237
# Epoch [3/10], Step [50/235], Train Loss: 0.1435
# Epoch [3/10], Step [75/235], Train Loss: 0.1088
# Epoch [3/10], Step [100/235], Train Loss: 0.1051
# Epoch [3/10], Step [125/235], Train Loss: 0.1814
# Epoch [3/10], Step [150/235], Train Loss: 0.0728
# Epoch [3/10], Step [175/235], Train Loss: 0.0749
# Epoch [3/10], Step [200/235], Train Loss: 0.1117
# Epoch [3/10], Step [225/235], Train Loss: 0.1605
# Epoch [3/10], Train Accuracy: 0.9723
# Epoch [3/10], Test Accuracy: 0.9635
# Epoch [4/10], Step [25/235], Train Loss: 0.0986
# Epoch [4/10], Step [50/235], Train Loss: 0.0628
# Epoch [4/10], Step [75/235], Train Loss: 0.1185
# Epoch [4/10], Step [100/235], Train Loss: 0.0846
# Epoch [4/10], Step [125/235], Train Loss: 0.1701
# Epoch [4/10], Step [150/235], Train Loss: 0.1268
# Epoch [4/10], Step [175/235], Train Loss: 0.0671
# Epoch [4/10], Step [200/235], Train Loss: 0.0471
# Epoch [4/10], Step [225/235], Train Loss: 0.1021
# Epoch [4/10], Train Accuracy: 0.9780
# Epoch [4/10], Test Accuracy: 0.9670
# Epoch [5/10], Step [25/235], Train Loss: 0.0568
# Epoch [5/10], Step [50/235], Train Loss: 0.1214
# Epoch [5/10], Step [75/235], Train Loss: 0.1021
# Epoch [5/10], Step [100/235], Train Loss: 0.2762
# Epoch [5/10], Step [125/235], Train Loss: 0.1129
# Epoch [5/10], Step [150/235], Train Loss: 0.0619
# Epoch [5/10], Step [175/235], Train Loss: 0.1403
# Epoch [5/10], Step [200/235], Train Loss: 0.0785
# Epoch [5/10], Step [225/235], Train Loss: 0.1025
# Epoch [5/10], Train Accuracy: 0.9749
# Epoch [5/10], Test Accuracy: 0.9651
# Epoch [6/10], Step [25/235], Train Loss: 0.2004
# Epoch [6/10], Step [50/235], Train Loss: 0.1234
# Epoch [6/10], Step [75/235], Train Loss: 0.0325
# Epoch [6/10], Step [100/235], Train Loss: 0.1225
# Epoch [6/10], Step [125/235], Train Loss: 0.1152
# Epoch [6/10], Step [150/235], Train Loss: 0.1013
# Epoch [6/10], Step [175/235], Train Loss: 0.0407
# Epoch [6/10], Step [200/235], Train Loss: 0.1618
# Epoch [6/10], Step [225/235], Train Loss: 0.1026
# Epoch [6/10], Train Accuracy: 0.9777
# Epoch [6/10], Test Accuracy: 0.9649
# Epoch [7/10], Step [25/235], Train Loss: 0.0729
# Epoch [7/10], Step [50/235], Train Loss: 0.0701
# Epoch [7/10], Step [75/235], Train Loss: 0.0941
# Epoch [7/10], Step [100/235], Train Loss: 0.1135
# Epoch [7/10], Step [125/235], Train Loss: 0.0628
# Epoch [7/10], Step [150/235], Train Loss: 0.2980
# Epoch [7/10], Step [175/235], Train Loss: 0.2607
# Epoch [7/10], Step [200/235], Train Loss: 0.0752
# Epoch [7/10], Step [225/235], Train Loss: 0.0261
# Epoch [7/10], Train Accuracy: 0.9796
# Epoch [7/10], Test Accuracy: 0.9677
# Epoch [8/10], Step [25/235], Train Loss: 0.1045
# Epoch [8/10], Step [50/235], Train Loss: 0.1072
# Epoch [8/10], Step [75/235], Train Loss: 0.1198
# Epoch [8/10], Step [100/235], Train Loss: 0.0875
# Epoch [8/10], Step [125/235], Train Loss: 0.0977
# Epoch [8/10], Step [150/235], Train Loss: 0.0994
# Epoch [8/10], Step [175/235], Train Loss: 0.0640
# Epoch [8/10], Step [200/235], Train Loss: 0.0937
# Epoch [8/10], Step [225/235], Train Loss: 0.0935
# Epoch [8/10], Train Accuracy: 0.9815
# Epoch [8/10], Test Accuracy: 0.9680
# Epoch [9/10], Step [25/235], Train Loss: 0.0198
# Epoch [9/10], Step [50/235], Train Loss: 0.0354
# Epoch [9/10], Step [75/235], Train Loss: 0.0891
# Epoch [9/10], Step [100/235], Train Loss: 0.0764
# Epoch [9/10], Step [125/235], Train Loss: 0.0372
# Epoch [9/10], Step [150/235], Train Loss: 0.0439
# Epoch [9/10], Step [175/235], Train Loss: 0.1046
# Epoch [9/10], Step [200/235], Train Loss: 0.1244
# Epoch [9/10], Step [225/235], Train Loss: 0.0325
# Epoch [9/10], Train Accuracy: 0.9827
# Epoch [9/10], Test Accuracy: 0.9692
# Epoch [10/10], Step [25/235], Train Loss: 0.1552
# Epoch [10/10], Step [50/235], Train Loss: 0.0468
# Epoch [10/10], Step [75/235], Train Loss: 0.0520
# Epoch [10/10], Step [100/235], Train Loss: 0.0775
# Epoch [10/10], Step [125/235], Train Loss: 0.0672
# Epoch [10/10], Step [150/235], Train Loss: 0.0326
# Epoch [10/10], Step [175/235], Train Loss: 0.0545
# Epoch [10/10], Step [200/235], Train Loss: 0.0673
# Epoch [10/10], Step [225/235], Train Loss: 0.0075
# Epoch [10/10], Train Accuracy: 0.9869
# Epoch [10/10], Test Accuracy: 0.9724

# %%
# Train a second model with 3 layers
model3 = DeepNeuralNet(n_x = 784, n_h = [40, 20], n_y = 10).to(device)
train_accs3, test_accs3 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.1231
# Epoch [1/10], Step [50/235], Train Loss: 0.0345
# Epoch [1/10], Step [75/235], Train Loss: 0.0315
# Epoch [1/10], Step [100/235], Train Loss: 0.1053
# Epoch [1/10], Step [125/235], Train Loss: 0.0353
# Epoch [1/10], Step [150/235], Train Loss: 0.1532
# Epoch [1/10], Step [175/235], Train Loss: 0.0426
# Epoch [1/10], Step [200/235], Train Loss: 0.0891
# Epoch [1/10], Step [225/235], Train Loss: 0.0590
# Epoch [1/10], Train Accuracy: 0.9793
# Epoch [1/10], Test Accuracy: 0.9668
# Epoch [2/10], Step [25/235], Train Loss: 0.0324
# Epoch [2/10], Step [50/235], Train Loss: 0.0292
# Epoch [2/10], Step [75/235], Train Loss: 0.0582
# Epoch [2/10], Step [100/235], Train Loss: 0.0701
# Epoch [2/10], Step [125/235], Train Loss: 0.0641
# Epoch [2/10], Step [150/235], Train Loss: 0.0972
# Epoch [2/10], Step [175/235], Train Loss: 0.0617
# Epoch [2/10], Step [200/235], Train Loss: 0.0814
# Epoch [2/10], Step [225/235], Train Loss: 0.0663
# Epoch [2/10], Train Accuracy: 0.9839
# Epoch [2/10], Test Accuracy: 0.9693
# Epoch [3/10], Step [25/235], Train Loss: 0.0650
# Epoch [3/10], Step [50/235], Train Loss: 0.0996
# Epoch [3/10], Step [75/235], Train Loss: 0.0719
# Epoch [3/10], Step [100/235], Train Loss: 0.0272
# Epoch [3/10], Step [125/235], Train Loss: 0.0994
# Epoch [3/10], Step [150/235], Train Loss: 0.1139
# Epoch [3/10], Step [175/235], Train Loss: 0.0506
# Epoch [3/10], Step [200/235], Train Loss: 0.0721
# Epoch [3/10], Step [225/235], Train Loss: 0.0421
# Epoch [3/10], Train Accuracy: 0.9806
# Epoch [3/10], Test Accuracy: 0.9667
# Epoch [4/10], Step [25/235], Train Loss: 0.0456
# Epoch [4/10], Step [50/235], Train Loss: 0.0612
# Epoch [4/10], Step [75/235], Train Loss: 0.0167
# Epoch [4/10], Step [100/235], Train Loss: 0.0922
# Epoch [4/10], Step [125/235], Train Loss: 0.0411
# Epoch [4/10], Step [150/235], Train Loss: 0.0944
# Epoch [4/10], Step [175/235], Train Loss: 0.0249
# Epoch [4/10], Step [200/235], Train Loss: 0.1152
# Epoch [4/10], Step [225/235], Train Loss: 0.0987
# Epoch [4/10], Train Accuracy: 0.9837
# Epoch [4/10], Test Accuracy: 0.9704
# Epoch [5/10], Step [25/235], Train Loss: 0.0456
# Epoch [5/10], Step [50/235], Train Loss: 0.0652
# Epoch [5/10], Step [75/235], Train Loss: 0.0339
# Epoch [5/10], Step [100/235], Train Loss: 0.0733
# Epoch [5/10], Step [125/235], Train Loss: 0.0252
# Epoch [5/10], Step [150/235], Train Loss: 0.0950
# Epoch [5/10], Step [175/235], Train Loss: 0.0165
# Epoch [5/10], Step [200/235], Train Loss: 0.0452
# Epoch [5/10], Step [225/235], Train Loss: 0.0511
# Epoch [5/10], Train Accuracy: 0.9871
# Epoch [5/10], Test Accuracy: 0.9715
# Epoch [6/10], Step [25/235], Train Loss: 0.0077
# Epoch [6/10], Step [50/235], Train Loss: 0.0309
# Epoch [6/10], Step [75/235], Train Loss: 0.0173
# Epoch [6/10], Step [100/235], Train Loss: 0.0774
# Epoch [6/10], Step [125/235], Train Loss: 0.1110
# Epoch [6/10], Step [150/235], Train Loss: 0.0784
# Epoch [6/10], Step [175/235], Train Loss: 0.0432
# Epoch [6/10], Step [200/235], Train Loss: 0.0310
# Epoch [6/10], Step [225/235], Train Loss: 0.0512
# Epoch [6/10], Train Accuracy: 0.9863
# Epoch [6/10], Test Accuracy: 0.9708
# Epoch [7/10], Step [25/235], Train Loss: 0.0186
# Epoch [7/10], Step [50/235], Train Loss: 0.1228
# Epoch [7/10], Step [75/235], Train Loss: 0.0447
# Epoch [7/10], Step [100/235], Train Loss: 0.0650
# Epoch [7/10], Step [125/235], Train Loss: 0.1067
# Epoch [7/10], Step [150/235], Train Loss: 0.0420
# Epoch [7/10], Step [175/235], Train Loss: 0.1259
# Epoch [7/10], Step [200/235], Train Loss: 0.0927
# Epoch [7/10], Step [225/235], Train Loss: 0.0681
# Epoch [7/10], Train Accuracy: 0.9807
# Epoch [7/10], Test Accuracy: 0.9654
# Epoch [8/10], Step [25/235], Train Loss: 0.0652
# Epoch [8/10], Step [50/235], Train Loss: 0.0674
# Epoch [8/10], Step [75/235], Train Loss: 0.0690
# Epoch [8/10], Step [100/235], Train Loss: 0.0469
# Epoch [8/10], Step [125/235], Train Loss: 0.0454
# Epoch [8/10], Step [150/235], Train Loss: 0.0882
# Epoch [8/10], Step [175/235], Train Loss: 0.0637
# Epoch [8/10], Step [200/235], Train Loss: 0.0822
# Epoch [8/10], Step [225/235], Train Loss: 0.0922
# Epoch [8/10], Train Accuracy: 0.9833
# Epoch [8/10], Test Accuracy: 0.9666
# Epoch [9/10], Step [25/235], Train Loss: 0.0327
# Epoch [9/10], Step [50/235], Train Loss: 0.0636
# Epoch [9/10], Step [75/235], Train Loss: 0.0141
# Epoch [9/10], Step [100/235], Train Loss: 0.0072
# Epoch [9/10], Step [125/235], Train Loss: 0.1907
# Epoch [9/10], Step [150/235], Train Loss: 0.0693
# Epoch [9/10], Step [175/235], Train Loss: 0.0472
# Epoch [9/10], Step [200/235], Train Loss: 0.0149
# Epoch [9/10], Step [225/235], Train Loss: 0.0815
# Epoch [9/10], Train Accuracy: 0.9888
# Epoch [9/10], Test Accuracy: 0.9726
# Epoch [10/10], Step [25/235], Train Loss: 0.0157
# Epoch [10/10], Step [50/235], Train Loss: 0.0215
# Epoch [10/10], Step [75/235], Train Loss: 0.0476
# Epoch [10/10], Step [100/235], Train Loss: 0.0186
# Epoch [10/10], Step [125/235], Train Loss: 0.0504
# Epoch [10/10], Step [150/235], Train Loss: 0.0260
# Epoch [10/10], Step [175/235], Train Loss: 0.0215
# Epoch [10/10], Step [200/235], Train Loss: 0.1009
# Epoch [10/10], Step [225/235], Train Loss: 0.1087
# Epoch [10/10], Train Accuracy: 0.9848
# Epoch [10/10], Test Accuracy: 0.9707

# %% [markdown]
# The first thing we can observe is that the training time seems to scale with the number of trainable parameters (total number of neurons in all layers combined togather).
#
# Looking at the performance curves below, we can see that all three models are able to train correctly without overfitting. They however achieve a close performance, therefore hinting at the fact that going for deep neural networks, is not necessarily better.
#
# In fact, we could obtain very similar results with less layers and smaller sizes.
#
# Note that this is a particular case, here, because MNIST is a very nice dataset and very hard to underfit or overfit. In the future, however, it would be a good practice to check different sizes for you deep neural network architecture and control whether you are underfitting, overfitting or fitting the data just right.
#
# As mentioned in the notebook 7 from W2, it would be also good practice to keep saves of your models during training times and eventually use the best model you have obtained after you have tried a few different hyperparameters (number of layers, number of neurons, learning rates, etc.).

# %%
plt.figure(figsize = (10, 7))
plt.plot(train_accs1, "r-", label = "Model 1 train acc.")
plt.plot(test_accs1, "b-", label = "Model 1 test acc.")
plt.plot(train_accs2, "r--", label = "Model 2 train acc.")
plt.plot(test_accs2, "b--", label = "Model 2 test acc.")
plt.plot(train_accs3, "r:", label = "Model 3 train acc.")
plt.plot(test_accs3, "b:", label = "Model 3 test acc.")
plt.legend(loc = "best")
plt.ylim([0.9, 1])
plt.show()

# %% [markdown]
# ### What's next?
#
# In this notebook, we were able to perform image recognition using Deep Neural Networks and obtained a rather good test accuracy of 96% after training. While this appears as not too bad, this mainly has to do with MNIST being a nice dataset. In  practice, when it comes to processing images passed as inputs, the fully connected/Linear layers are not really the best choice, and they might rapidly struggle once the images become more sophisticated (higher resolution than 28x28, no longer greyscale but RGB, etc.).
#
# Next week, we will discuss the convolution operation, which is a different operation than the $ Wx + b $ one, which can be used as a layer in Neural Networks, and see why it is far superior when it comes to processing images.
