# %% [markdown]
# # 8. PyTorch Basics - Good practices in Deep Learning Projects
#
# ### About this notebook
#
# This notebook was used in the 50.039 Deep Learning course at the Singapore University of Technology and Design.
#
# **Author:** Matthieu DE MARI (matthieu_demari@sutd.edu.sg)
#
# **Version:** 1.3 (09/02/2025)
#
# **Requirements:**
# - Python 3 (tested on v3.13.1)
# - Matplotlib (tested on v3.10.0)
# - Numpy (tested on v2.2.1)
# - Torch (tested on v2.7.0+cu124)
# - Torchvision (tested on v0.22.0+cu124)

# %% [markdown]
# ### Imports and CUDA

# %%
# Matplotlib
import matplotlib.pyplot as plt
# Numpy
import numpy as np
# Torch
import torch
import torchvision
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Compose, Normalize
from torchvision.datasets import MNIST

# %%
# Use GPU if available, else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### The MNIST Dataset
#
# As in the previous notebook

# %%
# Define transform to convert images to tensors and normalize them
transform_data = Compose([ToTensor(),
                          Normalize((0.1307,), (0.3081,))])

# Load the data
batch_size = 256
train_dataset = MNIST(root='./mnist/', train = True, download = True, transform = transform_data)
test_dataset = MNIST(root='./mnist/', train = False, download = True, transform = transform_data)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 9.91M/9.91M [00:04<00:00, 2.17MB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 28.9k/28.9k [00:00<00:00, 118kB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 1.65M/1.65M [00:03<00:00, 530kB/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 4.54k/4.54k [00:00<00:00, 5.54MB/s]

# %% [markdown]
# ### Our deep neural network
#
# As in the previous notebook.
#
# However, we have stremalined the DeepNeuralNet class and its init method so that it can work with any number of elements in the list n_h (instead of just 3). The Sequential will then adjust automatically to produce any appropriate number of DenseReLU layers and finish with a single DenseSoftmax one.

# %%
class DenseReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        # Using ReLU operation as activation after
        return torch.relu(self.fc(x))

# %%
class DenseNoReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        return self.fc(x)

# %%
class DeepNeuralNet(torch.nn.Module):
    def __init__(self, n_x, n_h, n_y):
        super().__init__()
        # Define the correct number of Dense + ReLU layers based on n_h,
        # followed by one final Dense + Softmax layer
        values = [n_x] + n_h
        self.processing_layers = [DenseReLU(values[i], values[i + 1]) for i in range(len(values) - 1)]
        self.processing_layers += [DenseNoReLU(n_h[-1], n_y)]
        
        # Combine all layers
        # Important: note the * symbol before the list of layers in self.processing_layers
        # Not sure what it does? Check the *args and **kwargs concepts in Python.
        self.combined_layers = torch.nn.Sequential(*self.processing_layers)

    
    def forward(self, x):
        # Flatten images (transform them from 28x28 2D matrices to 784 1D vectors)
        x = x.view(x.size(0), -1)
        # Pass through all four layers
        out = self.combined_layers(x)
        return out

# %% [markdown]
# Let us try our Deep Neural Net class with more layers, e.g. n_h $ = [320, 160, 80, 40, 20] $.

# %%
# Initialize the model
model = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
# Set model in train mode!
model.train()
# This will display a recap of the different layers
print(model.modules)
# Out:
# <bound method Module.modules of DeepNeuralNet(
#   (combined_layers): Sequential(
#     (0): DenseReLU(
#       (fc): Linear(in_features=784, out_features=320, bias=True)
#     )
#     (1): DenseReLU(
#       (fc): Linear(in_features=320, out_features=160, bias=True)
#     )
#     (2): DenseReLU(
#       (fc): Linear(in_features=160, out_features=80, bias=True)
#     )
#     (3): DenseReLU(
#       (fc): Linear(in_features=80, out_features=40, bias=True)
#     )
#     (4): DenseReLU(
#       (fc): Linear(in_features=40, out_features=20, bias=True)
#     )
#     (5): DenseNoReLU(
#       (fc): Linear(in_features=20, out_features=10, bias=True)
#     )
#   )
# )>

# %% [markdown]
# ### Number of layers/neurons vs overfitting tradeoff
#
# In the previous noteboo, we raised a fairly important question: **what is the appropriate number of layers to use and how many neurons should we use on each layer?**
#
# We established that there is no fixed rule for how many layers should be used in a deep neural network. Instead, the number of layers, as well as the number of neurons in each layer, should be chosen based on the complexity of the task and the amount of available data.
#
# In general, deep neural networks with many layers (hundreds or even thousands) can learn very complex patterns in data, but they also require a large amount of data and computational resources to train. If the network is too deep, it may also be prone to overfitting, which can hinder its generalization performance on unseen data.
#
# On the other hand, shallow networks with fewer layers may be easier to train and require less data, but they may not be able to learn as complex patterns and may not achieve as high performance on some tasks.
#
# Finding the optimal number of layers and the optimal architecture of a deep neural network is often a trade-off between model complexity, computational resources, and performance, and requires some experimentation and model selection.

# %% [markdown]
# ### Before we continue, reworking the trainer() function to get performance curves
#
# We just add two lists keeping track of the train and test accuracies during training. Values will be appended to them during training. The entire code is then brought into a trainer() function for convenience.

# %%
def trainer(model, train_loader, test_loader):
    
    # History for train acc, test acc
    train_accs = []
    test_accs = []
    
    # Define optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr = 1e-2)

    # Training model
    num_epochs = 10
    for epoch in range(num_epochs):

        # Go trough all samples in train dataset
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            # Get from dataloader and send to device
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)

            # Compute loss
            loss = torch.nn.functional.cross_entropy(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Display
            if (i+1) % 25 == 0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Train Loss: {loss.item():.4f}')

        # Compute model train accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in train_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        train_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Accuracy: {train_accuracy:.4f}')
        train_accs.append(train_accuracy)
        
        # Compute model test accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in test_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        test_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {test_accuracy:.4f}')
        test_accs.append(test_accuracy)
        
    # Return
    return train_accs, test_accs

# %% [markdown]
# Let us now try to train three different models:
# - One model with 6 layers (n_h = [320, 160, 80, 40, 20]),
# - One model with three layers (n_h = [400, 200]),
# - And one model with three layers, but smaller ones (n_h = [40, 20]).

# %%
# Train a first model with 6 layers
model1 = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
train_accs1, test_accs1 = trainer(model1, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.8016
# Epoch [1/10], Step [50/235], Train Loss: 0.5599
# Epoch [1/10], Step [75/235], Train Loss: 0.3992
# Epoch [1/10], Step [100/235], Train Loss: 0.1747
# Epoch [1/10], Step [125/235], Train Loss: 0.2950
# Epoch [1/10], Step [150/235], Train Loss: 0.2365
# Epoch [1/10], Step [175/235], Train Loss: 0.1528
# Epoch [1/10], Step [200/235], Train Loss: 0.2389
# Epoch [1/10], Step [225/235], Train Loss: 0.1514
# Epoch [1/10], Train Accuracy: 0.9550
# Epoch [1/10], Test Accuracy: 0.9514
# Epoch [2/10], Step [25/235], Train Loss: 0.1705
# Epoch [2/10], Step [50/235], Train Loss: 0.1813
# Epoch [2/10], Step [75/235], Train Loss: 0.1700
# Epoch [2/10], Step [100/235], Train Loss: 0.1541
# Epoch [2/10], Step [125/235], Train Loss: 0.1196
# Epoch [2/10], Step [150/235], Train Loss: 0.2075
# Epoch [2/10], Step [175/235], Train Loss: 0.1978
# Epoch [2/10], Step [200/235], Train Loss: 0.1129
# Epoch [2/10], Step [225/235], Train Loss: 0.1116
# Epoch [2/10], Train Accuracy: 0.9697
# Epoch [2/10], Test Accuracy: 0.9653
# Epoch [3/10], Step [25/235], Train Loss: 0.1511
# Epoch [3/10], Step [50/235], Train Loss: 0.1179
# Epoch [3/10], Step [75/235], Train Loss: 0.1014
# Epoch [3/10], Step [100/235], Train Loss: 0.1464
# Epoch [3/10], Step [125/235], Train Loss: 0.0954
# Epoch [3/10], Step [150/235], Train Loss: 0.1551
# Epoch [3/10], Step [175/235], Train Loss: 0.1016
# Epoch [3/10], Step [200/235], Train Loss: 0.0425
# Epoch [3/10], Step [225/235], Train Loss: 0.2505
# Epoch [3/10], Train Accuracy: 0.9744
# Epoch [3/10], Test Accuracy: 0.9668
# Epoch [4/10], Step [25/235], Train Loss: 0.1076
# Epoch [4/10], Step [50/235], Train Loss: 0.1156
# Epoch [4/10], Step [75/235], Train Loss: 0.1033
# Epoch [4/10], Step [100/235], Train Loss: 0.1433
# Epoch [4/10], Step [125/235], Train Loss: 0.0956
# Epoch [4/10], Step [150/235], Train Loss: 0.0909
# Epoch [4/10], Step [175/235], Train Loss: 0.0379
# Epoch [4/10], Step [200/235], Train Loss: 0.0455
# Epoch [4/10], Step [225/235], Train Loss: 0.0752
# Epoch [4/10], Train Accuracy: 0.9782
# Epoch [4/10], Test Accuracy: 0.9687
# Epoch [5/10], Step [25/235], Train Loss: 0.1047
# Epoch [5/10], Step [50/235], Train Loss: 0.1439
# Epoch [5/10], Step [75/235], Train Loss: 0.1100
# Epoch [5/10], Step [100/235], Train Loss: 0.1291
# Epoch [5/10], Step [125/235], Train Loss: 0.0582
# Epoch [5/10], Step [150/235], Train Loss: 0.1826
# Epoch [5/10], Step [175/235], Train Loss: 0.1105
# Epoch [5/10], Step [200/235], Train Loss: 0.1129
# Epoch [5/10], Step [225/235], Train Loss: 0.1082
# Epoch [5/10], Train Accuracy: 0.9813
# Epoch [5/10], Test Accuracy: 0.9720
# Epoch [6/10], Step [25/235], Train Loss: 0.0508
# Epoch [6/10], Step [50/235], Train Loss: 0.0874
# Epoch [6/10], Step [75/235], Train Loss: 0.0632
# Epoch [6/10], Step [100/235], Train Loss: 0.1203
# Epoch [6/10], Step [125/235], Train Loss: 0.1523
# Epoch [6/10], Step [150/235], Train Loss: 0.1027
# Epoch [6/10], Step [175/235], Train Loss: 0.1002
# Epoch [6/10], Step [200/235], Train Loss: 0.1186
# Epoch [6/10], Step [225/235], Train Loss: 0.1014
# Epoch [6/10], Train Accuracy: 0.9823
# Epoch [6/10], Test Accuracy: 0.9737
# Epoch [7/10], Step [25/235], Train Loss: 0.0867
# Epoch [7/10], Step [50/235], Train Loss: 0.0300
# Epoch [7/10], Step [75/235], Train Loss: 0.0138
# Epoch [7/10], Step [100/235], Train Loss: 0.0744
# Epoch [7/10], Step [125/235], Train Loss: 0.0996
# Epoch [7/10], Step [150/235], Train Loss: 0.0276
# Epoch [7/10], Step [175/235], Train Loss: 0.0934
# Epoch [7/10], Step [200/235], Train Loss: 0.0973
# Epoch [7/10], Step [225/235], Train Loss: 0.0564
# Epoch [7/10], Train Accuracy: 0.9859
# Epoch [7/10], Test Accuracy: 0.9729
# Epoch [8/10], Step [25/235], Train Loss: 0.0744
# Epoch [8/10], Step [50/235], Train Loss: 0.1270
# Epoch [8/10], Step [75/235], Train Loss: 0.0613
# Epoch [8/10], Step [100/235], Train Loss: 0.1234
# Epoch [8/10], Step [125/235], Train Loss: 0.0523
# Epoch [8/10], Step [150/235], Train Loss: 0.0326
# Epoch [8/10], Step [175/235], Train Loss: 0.0830
# Epoch [8/10], Step [200/235], Train Loss: 0.0632
# Epoch [8/10], Step [225/235], Train Loss: 0.0671
# Epoch [8/10], Train Accuracy: 0.9830
# Epoch [8/10], Test Accuracy: 0.9730
# Epoch [9/10], Step [25/235], Train Loss: 0.1270
# Epoch [9/10], Step [50/235], Train Loss: 0.1252
# Epoch [9/10], Step [75/235], Train Loss: 0.0314
# Epoch [9/10], Step [100/235], Train Loss: 0.0683
# Epoch [9/10], Step [125/235], Train Loss: 0.0596
# Epoch [9/10], Step [150/235], Train Loss: 0.0707
# Epoch [9/10], Step [175/235], Train Loss: 0.0981
# Epoch [9/10], Step [200/235], Train Loss: 0.0577
# Epoch [9/10], Step [225/235], Train Loss: 0.0650
# Epoch [9/10], Train Accuracy: 0.9803
# Epoch [9/10], Test Accuracy: 0.9690
# Epoch [10/10], Step [25/235], Train Loss: 0.0691
# Epoch [10/10], Step [50/235], Train Loss: 0.0644
# Epoch [10/10], Step [75/235], Train Loss: 0.0613
# Epoch [10/10], Step [100/235], Train Loss: 0.1012
# Epoch [10/10], Step [125/235], Train Loss: 0.0736
# Epoch [10/10], Step [150/235], Train Loss: 0.1126
# Epoch [10/10], Step [175/235], Train Loss: 0.0461
# Epoch [10/10], Step [200/235], Train Loss: 0.0964
# Epoch [10/10], Step [225/235], Train Loss: 0.0289
# Epoch [10/10], Train Accuracy: 0.9851
# Epoch [10/10], Test Accuracy: 0.9727

# %%
# Train a second model with 3 layers
model2 = DeepNeuralNet(n_x = 784, n_h = [400, 200], n_y = 10).to(device)
train_accs2, test_accs2 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.3825
# Epoch [1/10], Step [50/235], Train Loss: 0.2085
# Epoch [1/10], Step [75/235], Train Loss: 0.3521
# Epoch [1/10], Step [100/235], Train Loss: 0.2236
# Epoch [1/10], Step [125/235], Train Loss: 0.1521
# Epoch [1/10], Step [150/235], Train Loss: 0.1482
# Epoch [1/10], Step [175/235], Train Loss: 0.1940
# Epoch [1/10], Step [200/235], Train Loss: 0.1156
# Epoch [1/10], Step [225/235], Train Loss: 0.1409
# Epoch [1/10], Train Accuracy: 0.9614
# Epoch [1/10], Test Accuracy: 0.9546
# Epoch [2/10], Step [25/235], Train Loss: 0.2694
# Epoch [2/10], Step [50/235], Train Loss: 0.2182
# Epoch [2/10], Step [75/235], Train Loss: 0.1504
# Epoch [2/10], Step [100/235], Train Loss: 0.1279
# Epoch [2/10], Step [125/235], Train Loss: 0.1626
# Epoch [2/10], Step [150/235], Train Loss: 0.1136
# Epoch [2/10], Step [175/235], Train Loss: 0.1250
# Epoch [2/10], Step [200/235], Train Loss: 0.1549
# Epoch [2/10], Step [225/235], Train Loss: 0.1525
# Epoch [2/10], Train Accuracy: 0.9736
# Epoch [2/10], Test Accuracy: 0.9634
# Epoch [3/10], Step [25/235], Train Loss: 0.1701
# Epoch [3/10], Step [50/235], Train Loss: 0.0940
# Epoch [3/10], Step [75/235], Train Loss: 0.0648
# Epoch [3/10], Step [100/235], Train Loss: 0.0859
# Epoch [3/10], Step [125/235], Train Loss: 0.1196
# Epoch [3/10], Step [150/235], Train Loss: 0.1837
# Epoch [3/10], Step [175/235], Train Loss: 0.1104
# Epoch [3/10], Step [200/235], Train Loss: 0.0959
# Epoch [3/10], Step [225/235], Train Loss: 0.0806
# Epoch [3/10], Train Accuracy: 0.9750
# Epoch [3/10], Test Accuracy: 0.9658
# Epoch [4/10], Step [25/235], Train Loss: 0.0373
# Epoch [4/10], Step [50/235], Train Loss: 0.0677
# Epoch [4/10], Step [75/235], Train Loss: 0.1116
# Epoch [4/10], Step [100/235], Train Loss: 0.0761
# Epoch [4/10], Step [125/235], Train Loss: 0.1211
# Epoch [4/10], Step [150/235], Train Loss: 0.1296
# Epoch [4/10], Step [175/235], Train Loss: 0.0490
# Epoch [4/10], Step [200/235], Train Loss: 0.1460
# Epoch [4/10], Step [225/235], Train Loss: 0.0747
# Epoch [4/10], Train Accuracy: 0.9748
# Epoch [4/10], Test Accuracy: 0.9651
# Epoch [5/10], Step [25/235], Train Loss: 0.0690
# Epoch [5/10], Step [50/235], Train Loss: 0.1013
# Epoch [5/10], Step [75/235], Train Loss: 0.0514
# Epoch [5/10], Step [100/235], Train Loss: 0.0870
# Epoch [5/10], Step [125/235], Train Loss: 0.1042
# Epoch [5/10], Step [150/235], Train Loss: 0.0632
# Epoch [5/10], Step [175/235], Train Loss: 0.0759
# Epoch [5/10], Step [200/235], Train Loss: 0.1098
# Epoch [5/10], Step [225/235], Train Loss: 0.1491
# Epoch [5/10], Train Accuracy: 0.9761
# Epoch [5/10], Test Accuracy: 0.9650
# Epoch [6/10], Step [25/235], Train Loss: 0.0864
# Epoch [6/10], Step [50/235], Train Loss: 0.0393
# Epoch [6/10], Step [75/235], Train Loss: 0.0229
# Epoch [6/10], Step [100/235], Train Loss: 0.1556
# Epoch [6/10], Step [125/235], Train Loss: 0.0754
# Epoch [6/10], Step [150/235], Train Loss: 0.0152
# Epoch [6/10], Step [175/235], Train Loss: 0.0577
# Epoch [6/10], Step [200/235], Train Loss: 0.0519
# Epoch [6/10], Step [225/235], Train Loss: 0.0755
# Epoch [6/10], Train Accuracy: 0.9793
# Epoch [6/10], Test Accuracy: 0.9638
# Epoch [7/10], Step [25/235], Train Loss: 0.0888
# Epoch [7/10], Step [50/235], Train Loss: 0.0527
# Epoch [7/10], Step [75/235], Train Loss: 0.0387
# Epoch [7/10], Step [100/235], Train Loss: 0.0262
# Epoch [7/10], Step [125/235], Train Loss: 0.0915
# Epoch [7/10], Step [150/235], Train Loss: 0.0114
# Epoch [7/10], Step [175/235], Train Loss: 0.0749
# Epoch [7/10], Step [200/235], Train Loss: 0.1208
# Epoch [7/10], Step [225/235], Train Loss: 0.1148
# Epoch [7/10], Train Accuracy: 0.9797
# Epoch [7/10], Test Accuracy: 0.9642
# Epoch [8/10], Step [25/235], Train Loss: 0.0613
# Epoch [8/10], Step [50/235], Train Loss: 0.0099
# Epoch [8/10], Step [75/235], Train Loss: 0.0498
# Epoch [8/10], Step [100/235], Train Loss: 0.0932
# Epoch [8/10], Step [125/235], Train Loss: 0.0419
# Epoch [8/10], Step [150/235], Train Loss: 0.1174
# Epoch [8/10], Step [175/235], Train Loss: 0.1197
# Epoch [8/10], Step [200/235], Train Loss: 0.0862
# Epoch [8/10], Step [225/235], Train Loss: 0.0384
# Epoch [8/10], Train Accuracy: 0.9833
# Epoch [8/10], Test Accuracy: 0.9700
# Epoch [9/10], Step [25/235], Train Loss: 0.0899
# Epoch [9/10], Step [50/235], Train Loss: 0.0782
# Epoch [9/10], Step [75/235], Train Loss: 0.0362
# Epoch [9/10], Step [100/235], Train Loss: 0.0226
# Epoch [9/10], Step [125/235], Train Loss: 0.0979
# Epoch [9/10], Step [150/235], Train Loss: 0.1118
# Epoch [9/10], Step [175/235], Train Loss: 0.1228
# Epoch [9/10], Step [200/235], Train Loss: 0.1115
# Epoch [9/10], Step [225/235], Train Loss: 0.1202
# Epoch [9/10], Train Accuracy: 0.9831
# Epoch [9/10], Test Accuracy: 0.9691
# Epoch [10/10], Step [25/235], Train Loss: 0.0196
# Epoch [10/10], Step [50/235], Train Loss: 0.0242
# Epoch [10/10], Step [75/235], Train Loss: 0.0599
# Epoch [10/10], Step [100/235], Train Loss: 0.0715
# Epoch [10/10], Step [125/235], Train Loss: 0.1576
# Epoch [10/10], Step [150/235], Train Loss: 0.1337
# Epoch [10/10], Step [175/235], Train Loss: 0.0763
# Epoch [10/10], Step [200/235], Train Loss: 0.1415
# Epoch [10/10], Step [225/235], Train Loss: 0.0345
# Epoch [10/10], Train Accuracy: 0.9819
# Epoch [10/10], Test Accuracy: 0.9687

# %%
# Train a second model with 3 layers
model3 = DeepNeuralNet(n_x = 784, n_h = [40, 20], n_y = 10).to(device)
train_accs3, test_accs3 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.3009
# Epoch [1/10], Step [50/235], Train Loss: 0.0718
# Epoch [1/10], Step [75/235], Train Loss: 0.1274
# Epoch [1/10], Step [100/235], Train Loss: 0.2963
# Epoch [1/10], Step [125/235], Train Loss: 0.0760
# Epoch [1/10], Step [150/235], Train Loss: 0.0848
# Epoch [1/10], Step [175/235], Train Loss: 0.0364
# Epoch [1/10], Step [200/235], Train Loss: 0.1146
# Epoch [1/10], Step [225/235], Train Loss: 0.1701
# Epoch [1/10], Train Accuracy: 0.9811
# Epoch [1/10], Test Accuracy: 0.9659
# Epoch [2/10], Step [25/235], Train Loss: 0.0371
# Epoch [2/10], Step [50/235], Train Loss: 0.1098
# Epoch [2/10], Step [75/235], Train Loss: 0.0301
# Epoch [2/10], Step [100/235], Train Loss: 0.0477
# Epoch [2/10], Step [125/235], Train Loss: 0.0660
# Epoch [2/10], Step [150/235], Train Loss: 0.0653
# Epoch [2/10], Step [175/235], Train Loss: 0.0739
# Epoch [2/10], Step [200/235], Train Loss: 0.0660
# Epoch [2/10], Step [225/235], Train Loss: 0.0746
# Epoch [2/10], Train Accuracy: 0.9845
# Epoch [2/10], Test Accuracy: 0.9678
# Epoch [3/10], Step [25/235], Train Loss: 0.0415
# Epoch [3/10], Step [50/235], Train Loss: 0.0931
# Epoch [3/10], Step [75/235], Train Loss: 0.0307
# Epoch [3/10], Step [100/235], Train Loss: 0.0592
# Epoch [3/10], Step [125/235], Train Loss: 0.0850
# Epoch [3/10], Step [150/235], Train Loss: 0.0378
# Epoch [3/10], Step [175/235], Train Loss: 0.0386
# Epoch [3/10], Step [200/235], Train Loss: 0.0559
# Epoch [3/10], Step [225/235], Train Loss: 0.0306
# Epoch [3/10], Train Accuracy: 0.9838
# Epoch [3/10], Test Accuracy: 0.9668
# Epoch [4/10], Step [25/235], Train Loss: 0.0606
# Epoch [4/10], Step [50/235], Train Loss: 0.0553
# Epoch [4/10], Step [75/235], Train Loss: 0.0162
# Epoch [4/10], Step [100/235], Train Loss: 0.0470
# Epoch [4/10], Step [125/235], Train Loss: 0.1665
# Epoch [4/10], Step [150/235], Train Loss: 0.0693
# Epoch [4/10], Step [175/235], Train Loss: 0.0920
# Epoch [4/10], Step [200/235], Train Loss: 0.1024
# Epoch [4/10], Step [225/235], Train Loss: 0.0579
# Epoch [4/10], Train Accuracy: 0.9776
# Epoch [4/10], Test Accuracy: 0.9633
# Epoch [5/10], Step [25/235], Train Loss: 0.0055
# Epoch [5/10], Step [50/235], Train Loss: 0.0601
# Epoch [5/10], Step [75/235], Train Loss: 0.0431
# Epoch [5/10], Step [100/235], Train Loss: 0.0658
# Epoch [5/10], Step [125/235], Train Loss: 0.0562
# Epoch [5/10], Step [150/235], Train Loss: 0.0388
# Epoch [5/10], Step [175/235], Train Loss: 0.0844
# Epoch [5/10], Step [200/235], Train Loss: 0.0260
# Epoch [5/10], Step [225/235], Train Loss: 0.1251
# Epoch [5/10], Train Accuracy: 0.9840
# Epoch [5/10], Test Accuracy: 0.9679
# Epoch [6/10], Step [25/235], Train Loss: 0.1092
# Epoch [6/10], Step [50/235], Train Loss: 0.0960
# Epoch [6/10], Step [75/235], Train Loss: 0.1306
# Epoch [6/10], Step [100/235], Train Loss: 0.1819
# Epoch [6/10], Step [125/235], Train Loss: 0.0725
# Epoch [6/10], Step [150/235], Train Loss: 0.0529
# Epoch [6/10], Step [175/235], Train Loss: 0.1720
# Epoch [6/10], Step [200/235], Train Loss: 0.0715
# Epoch [6/10], Step [225/235], Train Loss: 0.0575
# Epoch [6/10], Train Accuracy: 0.9870
# Epoch [6/10], Test Accuracy: 0.9732
# Epoch [7/10], Step [25/235], Train Loss: 0.0300
# Epoch [7/10], Step [50/235], Train Loss: 0.0947
# Epoch [7/10], Step [75/235], Train Loss: 0.0193
# Epoch [7/10], Step [100/235], Train Loss: 0.0996
# Epoch [7/10], Step [125/235], Train Loss: 0.0381
# Epoch [7/10], Step [150/235], Train Loss: 0.0258
# Epoch [7/10], Step [175/235], Train Loss: 0.0375
# Epoch [7/10], Step [200/235], Train Loss: 0.0853
# Epoch [7/10], Step [225/235], Train Loss: 0.0501
# Epoch [7/10], Train Accuracy: 0.9862
# Epoch [7/10], Test Accuracy: 0.9685
# Epoch [8/10], Step [25/235], Train Loss: 0.0819
# Epoch [8/10], Step [50/235], Train Loss: 0.1016
# Epoch [8/10], Step [75/235], Train Loss: 0.1064
# Epoch [8/10], Step [100/235], Train Loss: 0.0726
# Epoch [8/10], Step [125/235], Train Loss: 0.0486
# Epoch [8/10], Step [150/235], Train Loss: 0.0628
# Epoch [8/10], Step [175/235], Train Loss: 0.0189
# Epoch [8/10], Step [200/235], Train Loss: 0.0145
# Epoch [8/10], Step [225/235], Train Loss: 0.0282
# Epoch [8/10], Train Accuracy: 0.9850
# Epoch [8/10], Test Accuracy: 0.9682
# Epoch [9/10], Step [25/235], Train Loss: 0.1052
# Epoch [9/10], Step [50/235], Train Loss: 0.0165
# Epoch [9/10], Step [75/235], Train Loss: 0.1866
# Epoch [9/10], Step [100/235], Train Loss: 0.0236
# Epoch [9/10], Step [125/235], Train Loss: 0.1116
# Epoch [9/10], Step [150/235], Train Loss: 0.0788
# Epoch [9/10], Step [175/235], Train Loss: 0.0604
# Epoch [9/10], Step [200/235], Train Loss: 0.1522
# Epoch [9/10], Step [225/235], Train Loss: 0.0501
# Epoch [9/10], Train Accuracy: 0.9818
# Epoch [9/10], Test Accuracy: 0.9659
# Epoch [10/10], Step [25/235], Train Loss: 0.0727
# Epoch [10/10], Step [50/235], Train Loss: 0.1183
# Epoch [10/10], Step [75/235], Train Loss: 0.0235
# Epoch [10/10], Step [100/235], Train Loss: 0.0510
# Epoch [10/10], Step [125/235], Train Loss: 0.0641
# Epoch [10/10], Step [150/235], Train Loss: 0.0355
# Epoch [10/10], Step [175/235], Train Loss: 0.0598
# Epoch [10/10], Step [200/235], Train Loss: 0.0077
# Epoch [10/10], Step [225/235], Train Loss: 0.0353
# Epoch [10/10], Train Accuracy: 0.9911
# Epoch [10/10], Test Accuracy: 0.9738

# %% [markdown]
# The first thing we can observe is that the training time seems to scale with the number of trainable parameters (total number of neurons in all layers combined togather).
#
# Looking at the performance curves below, we can see that all three models are able to train correctly without overfitting. They however achieve a close performance, therefore hinting at the fact that going for deep neural networks, is not necessarily better.
#
# In fact, we could obtain very similar results with less layers and smaller sizes.
#
# Note that this is a particular case, here, because MNIST is a very nice dataset and very hard to underfit or overfit. In the future, however, it would be a good practice to check different sizes for your deep neural network architecture and control whether you are underfitting, overfitting or fitting the data just right. Refer to Notebook 8 from W2 for details.
#
# As mentioned in the notebook 7 from W2, it would be also good practice to keep saves of your models during training times and eventually use the best model you have obtained after you have tried a few different hyperparameters (number of layers, number of neurons, learning rates, etc.).

# %%
plt.figure(figsize = (10, 7))
plt.plot(train_accs1, "r-", label = "Model 1 train acc.")
plt.plot(test_accs1, "b-", label = "Model 1 test acc.")
plt.plot(train_accs2, "r--", label = "Model 2 train acc.")
plt.plot(test_accs2, "b--", label = "Model 2 test acc.")
plt.plot(train_accs3, "r:", label = "Model 3 train acc.")
plt.plot(test_accs3, "b:", label = "Model 3 test acc.")
plt.legend(loc = "best")
plt.ylim([0.9, 1])
plt.show()

# %% [markdown]
# ### What's next?
#
# In this notebook, we were able to perform image recognition using Deep Neural Networks and obtained a rather good test accuracy of 96% after training. While this appears as not too bad, this mainly has to do with MNIST being a nice dataset. In  practice, when it comes to processing images passed as inputs, the fully connected/Linear layers are not really the best choice, and they might rapidly struggle once the images become more sophisticated (higher resolution than 28x28, no longer greyscale but RGB, etc.).
#
# Next week, we will discuss the convolution operation, which is a different operation than the $ Wx + b $ one, which can be used as a layer in Neural Networks, and see why it is far superior when it comes to processing images.
