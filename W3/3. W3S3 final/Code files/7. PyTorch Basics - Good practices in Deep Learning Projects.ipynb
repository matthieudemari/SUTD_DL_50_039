# %% [markdown]
# # 7. PyTorch Basics - Good practices in Deep Learning Projects
#
# ### About this notebook
#
# This notebook was used in the 50.039 Deep Learning course at the Singapore University of Technology and Design.
#
# **Author:** Matthieu DE MARI (matthieu_demari@sutd.edu.sg)
#
# **Version:** 1.1 (03/02/2022)
#
# **Requirements:**
# - Python 3 (tested on v3.9.6)
# - Matplotlib (tested on v3.5.1)
# - Numpy (tested on v1.22.1)
# - Torch (tested on v1.13.0)
# - Torchmetrics (tested on v0.11.0)

# %% [markdown]
# ### Imports and CUDA

# %%
# Matplotlib
import matplotlib.pyplot as plt
# Numpy
import numpy as np
# Torch
import torch
import torchvision
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor, Compose, Normalize
from torchvision.datasets import MNIST

# %%
# Use GPU if available, else use CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ### The MNIST Dataset
#
# As in the previous notebook

# %%
# Define transform to convert images to tensors and normalize them
transform_data = Compose([ToTensor(),
                          Normalize((0.1307,), (0.3081,))])

# Load the data
batch_size = 256
train_dataset = MNIST(root='./mnist/', train = True, download = True, transform = transform_data)
test_dataset = MNIST(root='./mnist/', train = False, download = True, transform = transform_data)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size = batch_size, shuffle = True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size = batch_size, shuffle = False)

# %% [markdown]
# ### Our deep neural network
#
# As in the previous notebook.
#
# However, we have stremalined the DeepNeuralNet class and its init method so that it can work with any number of elements in the list n_h (instead of just 3). The Sequential will then adjust automatically to produce any appropriate number of DenseReLU layers and finish with a single DenseSoftmax one.

# %%
class DenseReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        # Using ReLU operation as activation after
        return torch.relu(self.fc(x))

# %%
class DenseNoReLU(torch.nn.Module):
    def __init__(self, n_x, n_y):
        super().__init__()
        # Define Linear layer using the nn.Linear()
        self.fc = torch.nn.Linear(n_x, n_y)
    
    def forward(self, x):
        # Wx + b operation
        return self.fc(x)

# %%
class DeepNeuralNet(torch.nn.Module):
    def __init__(self, n_x, n_h, n_y):
        super().__init__()
        # Define the correct number of Dense + ReLU layers based on n_h,
        # followed by one final Dense + Softmax layer
        values = [n_x] + n_h
        self.processing_layers = [DenseReLU(values[i], values[i + 1]) for i in range(len(values) - 1)]
        self.processing_layers += [DenseNoReLU(n_h[-1], n_y)]
        
        # Combine all layers
        # Important: note the * symbol before the list of layers in self.processing_layers
        # Not sure what it does? Check the *args and **kwargs concepts in Python.
        self.combined_layers = torch.nn.Sequential(*self.processing_layers)

    
    def forward(self, x):
        # Flatten images (transform them from 28x28 2D matrices to 784 1D vectors)
        x = x.view(x.size(0), -1)
        # Pass through all four layers
        out = self.combined_layers(x)
        return out

# %% [markdown]
# Let us try our Deep Neural Net class with more layers, e.g. n_h $ = [320, 160, 80, 40, 20] $.

# %%
# Initialize the model
model = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
# Set model in train mode!
model.train()
# This will display a recap of the different layers
print(model.modules)
# Out:
# <bound method Module.modules of DeepNeuralNet(
#   (combined_layers): Sequential(
#     (0): DenseReLU(
#       (fc): Linear(in_features=784, out_features=320, bias=True)
#     )
#     (1): DenseReLU(
#       (fc): Linear(in_features=320, out_features=160, bias=True)
#     )
#     (2): DenseReLU(
#       (fc): Linear(in_features=160, out_features=80, bias=True)
#     )
#     (3): DenseReLU(
#       (fc): Linear(in_features=80, out_features=40, bias=True)
#     )
#     (4): DenseReLU(
#       (fc): Linear(in_features=40, out_features=20, bias=True)
#     )
#     (5): DenseNoReLU(
#       (fc): Linear(in_features=20, out_features=10, bias=True)
#     )
#   )
# )>

# %% [markdown]
# ### Number of layers/neurons vs overfitting tradeoff
#
# In the previous noteboo, we raised a fairly important question: **what is the appropriate number of layers to use and how many neurons should we use on each layer?**
#
# We established that there is no fixed rule for how many layers should be used in a deep neural network. Instead, the number of layers, as well as the number of neurons in each layer, should be chosen based on the complexity of the task and the amount of available data.
#
# In general, deep neural networks with many layers (hundreds or even thousands) can learn very complex patterns in data, but they also require a large amount of data and computational resources to train. If the network is too deep, it may also be prone to overfitting, which can hinder its generalization performance on unseen data.
#
# On the other hand, shallow networks with fewer layers may be easier to train and require less data, but they may not be able to learn as complex patterns and may not achieve as high performance on some tasks.
#
# Finding the optimal number of layers and the optimal architecture of a deep neural network is often a trade-off between model complexity, computational resources, and performance, and requires some experimentation and model selection.

# %% [markdown]
# ### Before we continue, reworking the trainer() function to get performance curves
#
# We just add two lists keeping track of the train and test accuracies during training. Values will be appended to them during training. The entire code is then brought into a trainer() function for convenience.

# %%
def trainer(model, train_loader, test_loader):
    
    # History for train acc, test acc
    train_accs = []
    test_accs = []
    
    # Define optimizer
    optimizer = torch.optim.Adam(model.parameters(), lr = 1e-2)

    # Training model
    num_epochs = 10
    for epoch in range(num_epochs):

        # Go trough all samples in train dataset
        model.train()
        for i, (images, labels) in enumerate(train_loader):
            # Get from dataloader and send to device
            images = images.to(device)
            labels = labels.to(device)

            # Forward pass
            outputs = model(images)

            # Compute loss
            loss = torch.nn.functional.cross_entropy(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Display
            if (i+1) % 25 == 0:
                print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Train Loss: {loss.item():.4f}')

        # Compute model train accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in train_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        train_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Train Accuracy: {train_accuracy:.4f}')
        train_accs.append(train_accuracy)
        
        # Compute model test accuracy on test after all samples have been seen using test samples
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in test_loader:
                # Get images and labels from test loader
                images = images.to(device)
                labels = labels.to(device)

                # Forward pass and predict class using max
                outputs = model(images)
                _, predicted = torch.max(outputs.data, 1)

                # Check if predicted class matches label and count numbler of correct predictions
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        # Compute final accuracy and display
        test_accuracy = correct/total
        print(f'Epoch [{epoch+1}/{num_epochs}], Test Accuracy: {test_accuracy:.4f}')
        test_accs.append(test_accuracy)
        
    # Return
    return train_accs, test_accs

# %% [markdown]
# Let us now try to train three different models:
# - One model with 6 layers (n_h = [320, 160, 80, 40, 20]),
# - One model with three layers (n_h = [400, 200]),
# - And one model with three layers, but smaller ones (n_h = [40, 20]).

# %%
# Train a first model with 6 layers
model1 = DeepNeuralNet(n_x = 784, n_h = [320, 160, 80, 40, 20], n_y = 10).to(device)
train_accs1, test_accs1 = trainer(model1, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.8613
# Epoch [1/10], Step [50/235], Train Loss: 0.4818
# Epoch [1/10], Step [75/235], Train Loss: 0.3533
# Epoch [1/10], Step [100/235], Train Loss: 0.3782
# Epoch [1/10], Step [125/235], Train Loss: 0.3213
# Epoch [1/10], Step [150/235], Train Loss: 0.2377
# Epoch [1/10], Step [175/235], Train Loss: 0.2737
# Epoch [1/10], Step [200/235], Train Loss: 0.1161
# Epoch [1/10], Step [225/235], Train Loss: 0.2357
# Epoch [1/10], Train Accuracy: 0.9427
# Epoch [1/10], Test Accuracy: 0.9382
# Epoch [2/10], Step [25/235], Train Loss: 0.2483
# Epoch [2/10], Step [50/235], Train Loss: 0.2653
# Epoch [2/10], Step [75/235], Train Loss: 0.1764
# Epoch [2/10], Step [100/235], Train Loss: 0.1809
# Epoch [2/10], Step [125/235], Train Loss: 0.2591
# Epoch [2/10], Step [150/235], Train Loss: 0.1394
# Epoch [2/10], Step [175/235], Train Loss: 0.1349
# Epoch [2/10], Step [200/235], Train Loss: 0.0939
# Epoch [2/10], Step [225/235], Train Loss: 0.1635
# Epoch [2/10], Train Accuracy: 0.9680
# Epoch [2/10], Test Accuracy: 0.9627
# Epoch [3/10], Step [25/235], Train Loss: 0.1410
# Epoch [3/10], Step [50/235], Train Loss: 0.0937
# Epoch [3/10], Step [75/235], Train Loss: 0.1147
# Epoch [3/10], Step [100/235], Train Loss: 0.0547
# Epoch [3/10], Step [125/235], Train Loss: 0.0546
# Epoch [3/10], Step [150/235], Train Loss: 0.1058
# Epoch [3/10], Step [175/235], Train Loss: 0.0626
# Epoch [3/10], Step [200/235], Train Loss: 0.1024
# Epoch [3/10], Step [225/235], Train Loss: 0.1109
# Epoch [3/10], Train Accuracy: 0.9730
# Epoch [3/10], Test Accuracy: 0.9668
# Epoch [4/10], Step [25/235], Train Loss: 0.0971
# Epoch [4/10], Step [50/235], Train Loss: 0.1007
# Epoch [4/10], Step [75/235], Train Loss: 0.0501
# Epoch [4/10], Step [100/235], Train Loss: 0.0443
# Epoch [4/10], Step [125/235], Train Loss: 0.1885
# Epoch [4/10], Step [150/235], Train Loss: 0.0463
# Epoch [4/10], Step [175/235], Train Loss: 0.1774
# Epoch [4/10], Step [200/235], Train Loss: 0.1191
# Epoch [4/10], Step [225/235], Train Loss: 0.1133
# Epoch [4/10], Train Accuracy: 0.9745
# Epoch [4/10], Test Accuracy: 0.9682
# Epoch [5/10], Step [25/235], Train Loss: 0.0475
# Epoch [5/10], Step [50/235], Train Loss: 0.1303
# Epoch [5/10], Step [75/235], Train Loss: 0.1142
# Epoch [5/10], Step [100/235], Train Loss: 0.0134
# Epoch [5/10], Step [125/235], Train Loss: 0.1551
# Epoch [5/10], Step [150/235], Train Loss: 0.0434
# Epoch [5/10], Step [175/235], Train Loss: 0.1246
# Epoch [5/10], Step [200/235], Train Loss: 0.0661
# Epoch [5/10], Step [225/235], Train Loss: 0.0824
# Epoch [5/10], Train Accuracy: 0.9827
# Epoch [5/10], Test Accuracy: 0.9730
# Epoch [6/10], Step [25/235], Train Loss: 0.0733
# Epoch [6/10], Step [50/235], Train Loss: 0.1126
# Epoch [6/10], Step [75/235], Train Loss: 0.0361
# Epoch [6/10], Step [100/235], Train Loss: 0.0672
# Epoch [6/10], Step [125/235], Train Loss: 0.0756
# Epoch [6/10], Step [150/235], Train Loss: 0.0715
# Epoch [6/10], Step [175/235], Train Loss: 0.0508
# Epoch [6/10], Step [200/235], Train Loss: 0.0532
# Epoch [6/10], Step [225/235], Train Loss: 0.1008
# Epoch [6/10], Train Accuracy: 0.9841
# Epoch [6/10], Test Accuracy: 0.9715
# Epoch [7/10], Step [25/235], Train Loss: 0.0234
# Epoch [7/10], Step [50/235], Train Loss: 0.0176
# Epoch [7/10], Step [75/235], Train Loss: 0.0385
# Epoch [7/10], Step [100/235], Train Loss: 0.0308
# Epoch [7/10], Step [125/235], Train Loss: 0.0333
# Epoch [7/10], Step [150/235], Train Loss: 0.0920
# Epoch [7/10], Step [175/235], Train Loss: 0.0538
# Epoch [7/10], Step [200/235], Train Loss: 0.0909
# Epoch [7/10], Step [225/235], Train Loss: 0.0530
# Epoch [7/10], Train Accuracy: 0.9862
# Epoch [7/10], Test Accuracy: 0.9716
# Epoch [8/10], Step [25/235], Train Loss: 0.0486
# Epoch [8/10], Step [50/235], Train Loss: 0.0646
# Epoch [8/10], Step [75/235], Train Loss: 0.1012
# Epoch [8/10], Step [100/235], Train Loss: 0.0636
# Epoch [8/10], Step [125/235], Train Loss: 0.0506
# Epoch [8/10], Step [150/235], Train Loss: 0.0346
# Epoch [8/10], Step [175/235], Train Loss: 0.0612
# Epoch [8/10], Step [200/235], Train Loss: 0.0731
# Epoch [8/10], Step [225/235], Train Loss: 0.0760
# Epoch [8/10], Train Accuracy: 0.9797
# Epoch [8/10], Test Accuracy: 0.9658
# Epoch [9/10], Step [25/235], Train Loss: 0.0290
# Epoch [9/10], Step [50/235], Train Loss: 0.0591
# Epoch [9/10], Step [75/235], Train Loss: 0.0655
# Epoch [9/10], Step [100/235], Train Loss: 0.0548
# Epoch [9/10], Step [125/235], Train Loss: 0.0965
# Epoch [9/10], Step [150/235], Train Loss: 0.0146
# Epoch [9/10], Step [175/235], Train Loss: 0.1073
# Epoch [9/10], Step [200/235], Train Loss: 0.0605
# Epoch [9/10], Step [225/235], Train Loss: 0.0417
# Epoch [9/10], Train Accuracy: 0.9831
# Epoch [9/10], Test Accuracy: 0.9694
# Epoch [10/10], Step [25/235], Train Loss: 0.1143
# Epoch [10/10], Step [50/235], Train Loss: 0.0391
# Epoch [10/10], Step [75/235], Train Loss: 0.0424
# Epoch [10/10], Step [100/235], Train Loss: 0.0290
# Epoch [10/10], Step [125/235], Train Loss: 0.1410
# Epoch [10/10], Step [150/235], Train Loss: 0.0228
# Epoch [10/10], Step [175/235], Train Loss: 0.0655
# Epoch [10/10], Step [200/235], Train Loss: 0.0969
# Epoch [10/10], Step [225/235], Train Loss: 0.0374
# Epoch [10/10], Train Accuracy: 0.9847
# Epoch [10/10], Test Accuracy: 0.9738

# %%
# Train a second model with 3 layers
model2 = DeepNeuralNet(n_x = 784, n_h = [400, 200], n_y = 10).to(device)
train_accs2, test_accs2 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.3573
# Epoch [1/10], Step [50/235], Train Loss: 0.2515
# Epoch [1/10], Step [75/235], Train Loss: 0.1612
# Epoch [1/10], Step [100/235], Train Loss: 0.1880
# Epoch [1/10], Step [125/235], Train Loss: 0.0731
# Epoch [1/10], Step [150/235], Train Loss: 0.1123
# Epoch [1/10], Step [175/235], Train Loss: 0.1392
# Epoch [1/10], Step [200/235], Train Loss: 0.2164
# Epoch [1/10], Step [225/235], Train Loss: 0.2061
# Epoch [1/10], Train Accuracy: 0.9640
# Epoch [1/10], Test Accuracy: 0.9574
# Epoch [2/10], Step [25/235], Train Loss: 0.1542
# Epoch [2/10], Step [50/235], Train Loss: 0.1308
# Epoch [2/10], Step [75/235], Train Loss: 0.1281
# Epoch [2/10], Step [100/235], Train Loss: 0.2094
# Epoch [2/10], Step [125/235], Train Loss: 0.1752
# Epoch [2/10], Step [150/235], Train Loss: 0.1380
# Epoch [2/10], Step [175/235], Train Loss: 0.1887
# Epoch [2/10], Step [200/235], Train Loss: 0.1918
# Epoch [2/10], Step [225/235], Train Loss: 0.1516
# Epoch [2/10], Train Accuracy: 0.9655
# Epoch [2/10], Test Accuracy: 0.9551
# Epoch [3/10], Step [25/235], Train Loss: 0.1087
# Epoch [3/10], Step [50/235], Train Loss: 0.0683
# Epoch [3/10], Step [75/235], Train Loss: 0.0978
# Epoch [3/10], Step [100/235], Train Loss: 0.1147
# Epoch [3/10], Step [125/235], Train Loss: 0.1180
# Epoch [3/10], Step [150/235], Train Loss: 0.1284
# Epoch [3/10], Step [175/235], Train Loss: 0.2113
# Epoch [3/10], Step [200/235], Train Loss: 0.0670
# Epoch [3/10], Step [225/235], Train Loss: 0.0784
# Epoch [3/10], Train Accuracy: 0.9742
# Epoch [3/10], Test Accuracy: 0.9648
# Epoch [4/10], Step [25/235], Train Loss: 0.0628
# Epoch [4/10], Step [50/235], Train Loss: 0.0891
# Epoch [4/10], Step [75/235], Train Loss: 0.1026
# Epoch [4/10], Step [100/235], Train Loss: 0.1434
# Epoch [4/10], Step [125/235], Train Loss: 0.0810
# Epoch [4/10], Step [150/235], Train Loss: 0.0723
# Epoch [4/10], Step [175/235], Train Loss: 0.1244
# Epoch [4/10], Step [200/235], Train Loss: 0.0980
# Epoch [4/10], Step [225/235], Train Loss: 0.0851
# Epoch [4/10], Train Accuracy: 0.9694
# Epoch [4/10], Test Accuracy: 0.9576
# Epoch [5/10], Step [25/235], Train Loss: 0.0781
# Epoch [5/10], Step [50/235], Train Loss: 0.0661
# Epoch [5/10], Step [75/235], Train Loss: 0.0542
# Epoch [5/10], Step [100/235], Train Loss: 0.0952
# Epoch [5/10], Step [125/235], Train Loss: 0.0573
# Epoch [5/10], Step [150/235], Train Loss: 0.1787
# Epoch [5/10], Step [175/235], Train Loss: 0.0831
# Epoch [5/10], Step [200/235], Train Loss: 0.0979
# Epoch [5/10], Step [225/235], Train Loss: 0.1445
# Epoch [5/10], Train Accuracy: 0.9747
# Epoch [5/10], Test Accuracy: 0.9629
# Epoch [6/10], Step [25/235], Train Loss: 0.0703
# Epoch [6/10], Step [50/235], Train Loss: 0.0586
# Epoch [6/10], Step [75/235], Train Loss: 0.1351
# Epoch [6/10], Step [100/235], Train Loss: 0.1140
# Epoch [6/10], Step [125/235], Train Loss: 0.0793
# Epoch [6/10], Step [150/235], Train Loss: 0.1375
# Epoch [6/10], Step [175/235], Train Loss: 0.1733
# Epoch [6/10], Step [200/235], Train Loss: 0.1030
# Epoch [6/10], Step [225/235], Train Loss: 0.1593
# Epoch [6/10], Train Accuracy: 0.9781
# Epoch [6/10], Test Accuracy: 0.9654
# Epoch [7/10], Step [25/235], Train Loss: 0.0558
# Epoch [7/10], Step [50/235], Train Loss: 0.0796
# Epoch [7/10], Step [75/235], Train Loss: 0.0894
# Epoch [7/10], Step [100/235], Train Loss: 0.0607
# Epoch [7/10], Step [125/235], Train Loss: 0.0290
# Epoch [7/10], Step [150/235], Train Loss: 0.0811
# Epoch [7/10], Step [175/235], Train Loss: 0.0738
# Epoch [7/10], Step [200/235], Train Loss: 0.1206
# Epoch [7/10], Step [225/235], Train Loss: 0.0599
# Epoch [7/10], Train Accuracy: 0.9783
# Epoch [7/10], Test Accuracy: 0.9693
# Epoch [8/10], Step [25/235], Train Loss: 0.0726
# Epoch [8/10], Step [50/235], Train Loss: 0.0485
# Epoch [8/10], Step [75/235], Train Loss: 0.0418
# Epoch [8/10], Step [100/235], Train Loss: 0.0462
# Epoch [8/10], Step [125/235], Train Loss: 0.1128
# Epoch [8/10], Step [150/235], Train Loss: 0.0650
# Epoch [8/10], Step [175/235], Train Loss: 0.1337
# Epoch [8/10], Step [200/235], Train Loss: 0.2050
# Epoch [8/10], Step [225/235], Train Loss: 0.1098
# Epoch [8/10], Train Accuracy: 0.9768
# Epoch [8/10], Test Accuracy: 0.9605
# Epoch [9/10], Step [25/235], Train Loss: 0.0381
# Epoch [9/10], Step [50/235], Train Loss: 0.0908
# Epoch [9/10], Step [75/235], Train Loss: 0.0669
# Epoch [9/10], Step [100/235], Train Loss: 0.0769
# Epoch [9/10], Step [125/235], Train Loss: 0.1629
# Epoch [9/10], Step [150/235], Train Loss: 0.0428
# Epoch [9/10], Step [175/235], Train Loss: 0.0618
# Epoch [9/10], Step [200/235], Train Loss: 0.1402
# Epoch [9/10], Step [225/235], Train Loss: 0.0911
# Epoch [9/10], Train Accuracy: 0.9776
# Epoch [9/10], Test Accuracy: 0.9641
# Epoch [10/10], Step [25/235], Train Loss: 0.0305
# Epoch [10/10], Step [50/235], Train Loss: 0.0654
# Epoch [10/10], Step [75/235], Train Loss: 0.0617
# Epoch [10/10], Step [100/235], Train Loss: 0.0638
# Epoch [10/10], Step [125/235], Train Loss: 0.0257
# Epoch [10/10], Step [150/235], Train Loss: 0.0923
# Epoch [10/10], Step [175/235], Train Loss: 0.1589
# Epoch [10/10], Step [200/235], Train Loss: 0.1084
# Epoch [10/10], Step [225/235], Train Loss: 0.1074
# Epoch [10/10], Train Accuracy: 0.9831
# Epoch [10/10], Test Accuracy: 0.9675

# %%
# Train a second model with 3 layers
model3 = DeepNeuralNet(n_x = 784, n_h = [40, 20], n_y = 10).to(device)
train_accs3, test_accs3 = trainer(model2, train_loader, test_loader)
# Out:
# Epoch [1/10], Step [25/235], Train Loss: 0.0719
# Epoch [1/10], Step [50/235], Train Loss: 0.0386
# Epoch [1/10], Step [75/235], Train Loss: 0.0392
# Epoch [1/10], Step [100/235], Train Loss: 0.1522
# Epoch [1/10], Step [125/235], Train Loss: 0.1236
# Epoch [1/10], Step [150/235], Train Loss: 0.0637
# Epoch [1/10], Step [175/235], Train Loss: 0.1118
# Epoch [1/10], Step [200/235], Train Loss: 0.0617
# Epoch [1/10], Step [225/235], Train Loss: 0.0695
# Epoch [1/10], Train Accuracy: 0.9819
# Epoch [1/10], Test Accuracy: 0.9674
# Epoch [2/10], Step [25/235], Train Loss: 0.1103
# Epoch [2/10], Step [50/235], Train Loss: 0.1730
# Epoch [2/10], Step [75/235], Train Loss: 0.0875
# Epoch [2/10], Step [100/235], Train Loss: 0.0832
# Epoch [2/10], Step [125/235], Train Loss: 0.0091
# Epoch [2/10], Step [150/235], Train Loss: 0.0759
# Epoch [2/10], Step [175/235], Train Loss: 0.0224
# Epoch [2/10], Step [200/235], Train Loss: 0.1193
# Epoch [2/10], Step [225/235], Train Loss: 0.0714
# Epoch [2/10], Train Accuracy: 0.9848
# Epoch [2/10], Test Accuracy: 0.9686
# Epoch [3/10], Step [25/235], Train Loss: 0.0283
# Epoch [3/10], Step [50/235], Train Loss: 0.0146
# Epoch [3/10], Step [75/235], Train Loss: 0.0416
# Epoch [3/10], Step [100/235], Train Loss: 0.0369
# Epoch [3/10], Step [125/235], Train Loss: 0.0480
# Epoch [3/10], Step [150/235], Train Loss: 0.0420
# Epoch [3/10], Step [175/235], Train Loss: 0.1088
# Epoch [3/10], Step [200/235], Train Loss: 0.0534
# Epoch [3/10], Step [225/235], Train Loss: 0.0915
# Epoch [3/10], Train Accuracy: 0.9850
# Epoch [3/10], Test Accuracy: 0.9678
# Epoch [4/10], Step [25/235], Train Loss: 0.0824
# Epoch [4/10], Step [50/235], Train Loss: 0.0586
# Epoch [4/10], Step [75/235], Train Loss: 0.0142
# Epoch [4/10], Step [100/235], Train Loss: 0.0486
# Epoch [4/10], Step [125/235], Train Loss: 0.0847
# Epoch [4/10], Step [150/235], Train Loss: 0.0679
# Epoch [4/10], Step [175/235], Train Loss: 0.1735
# Epoch [4/10], Step [200/235], Train Loss: 0.0604
# Epoch [4/10], Step [225/235], Train Loss: 0.0328
# Epoch [4/10], Train Accuracy: 0.9795
# Epoch [4/10], Test Accuracy: 0.9666
# Epoch [5/10], Step [25/235], Train Loss: 0.0882
# Epoch [5/10], Step [50/235], Train Loss: 0.0147
# Epoch [5/10], Step [75/235], Train Loss: 0.0760
# Epoch [5/10], Step [100/235], Train Loss: 0.0181
# Epoch [5/10], Step [125/235], Train Loss: 0.0392
# Epoch [5/10], Step [150/235], Train Loss: 0.0324
# Epoch [5/10], Step [175/235], Train Loss: 0.0618
# Epoch [5/10], Step [200/235], Train Loss: 0.0770
# Epoch [5/10], Step [225/235], Train Loss: 0.0530
# Epoch [5/10], Train Accuracy: 0.9867
# Epoch [5/10], Test Accuracy: 0.9690
# Epoch [6/10], Step [25/235], Train Loss: 0.0321
# Epoch [6/10], Step [50/235], Train Loss: 0.0577
# Epoch [6/10], Step [75/235], Train Loss: 0.0540
# Epoch [6/10], Step [100/235], Train Loss: 0.0906
# Epoch [6/10], Step [125/235], Train Loss: 0.0100
# Epoch [6/10], Step [150/235], Train Loss: 0.0298
# Epoch [6/10], Step [175/235], Train Loss: 0.1031
# Epoch [6/10], Step [200/235], Train Loss: 0.0604
# Epoch [6/10], Step [225/235], Train Loss: 0.0667
# Epoch [6/10], Train Accuracy: 0.9840
# Epoch [6/10], Test Accuracy: 0.9674
# Epoch [7/10], Step [25/235], Train Loss: 0.0494
# Epoch [7/10], Step [50/235], Train Loss: 0.0234
# Epoch [7/10], Step [75/235], Train Loss: 0.0240
# Epoch [7/10], Step [100/235], Train Loss: 0.0454
# Epoch [7/10], Step [125/235], Train Loss: 0.0274
# Epoch [7/10], Step [150/235], Train Loss: 0.0381
# Epoch [7/10], Step [175/235], Train Loss: 0.1190
# Epoch [7/10], Step [200/235], Train Loss: 0.1219
# Epoch [7/10], Step [225/235], Train Loss: 0.0748
# Epoch [7/10], Train Accuracy: 0.9822
# Epoch [7/10], Test Accuracy: 0.9663
# Epoch [8/10], Step [25/235], Train Loss: 0.0248
# Epoch [8/10], Step [50/235], Train Loss: 0.0600
# Epoch [8/10], Step [75/235], Train Loss: 0.0538
# Epoch [8/10], Step [100/235], Train Loss: 0.0569
# Epoch [8/10], Step [125/235], Train Loss: 0.0965
# Epoch [8/10], Step [150/235], Train Loss: 0.0326
# Epoch [8/10], Step [175/235], Train Loss: 0.0658
# Epoch [8/10], Step [200/235], Train Loss: 0.0966
# Epoch [8/10], Step [225/235], Train Loss: 0.0130
# Epoch [8/10], Train Accuracy: 0.9873
# Epoch [8/10], Test Accuracy: 0.9688
# Epoch [9/10], Step [25/235], Train Loss: 0.0380
# Epoch [9/10], Step [50/235], Train Loss: 0.0275
# Epoch [9/10], Step [75/235], Train Loss: 0.0610
# Epoch [9/10], Step [100/235], Train Loss: 0.0479
# Epoch [9/10], Step [125/235], Train Loss: 0.0563
# Epoch [9/10], Step [150/235], Train Loss: 0.0596
# Epoch [9/10], Step [175/235], Train Loss: 0.0899
# Epoch [9/10], Step [200/235], Train Loss: 0.0327
# Epoch [9/10], Step [225/235], Train Loss: 0.0323
# Epoch [9/10], Train Accuracy: 0.9868
# Epoch [9/10], Test Accuracy: 0.9717
# Epoch [10/10], Step [25/235], Train Loss: 0.0348
# Epoch [10/10], Step [50/235], Train Loss: 0.0203
# Epoch [10/10], Step [75/235], Train Loss: 0.0075
# Epoch [10/10], Step [100/235], Train Loss: 0.0521
# Epoch [10/10], Step [125/235], Train Loss: 0.0304
# Epoch [10/10], Step [150/235], Train Loss: 0.0618
# Epoch [10/10], Step [175/235], Train Loss: 0.0361
# Epoch [10/10], Step [200/235], Train Loss: 0.0527
# Epoch [10/10], Step [225/235], Train Loss: 0.0510
# Epoch [10/10], Train Accuracy: 0.9845
# Epoch [10/10], Test Accuracy: 0.9678

# %% [markdown]
# The first thing we can observe is that the training time seems to scale with the number of trainable parameters (total number of neurons in all layers combined togather).
#
# Looking at the performance curves below, we can see that all three models are able to train correctly without overfitting. They however achieve a close performance, therefore hinting at the fact that going for deep neural networks, is not necessarily better.
#
# In fact, we could obtain very similar results with less layers and smaller sizes.
#
# Note that this is a particular case, here, because MNIST is a very nice dataset and very hard to underfit or overfit. In the future, however, it would be a good practice to check different sizes for you deep neural network architecture and control whether you are underfitting, overfitting or fitting the data just right.
#
# As mentioned in the notebook 7 from W2, it would be also good practice to keep saves of your models during training times and eventually use the best model you have obtained after you have tried a few different hyperparameters (number of layers, number of neurons, learning rates, etc.).

# %%
plt.figure(figsize = (10, 7))
plt.plot(train_accs1, "r-", label = "Model 1 train acc.")
plt.plot(test_accs1, "b-", label = "Model 1 test acc.")
plt.plot(train_accs2, "r--", label = "Model 2 train acc.")
plt.plot(test_accs2, "b--", label = "Model 2 test acc.")
plt.plot(train_accs3, "r:", label = "Model 3 train acc.")
plt.plot(test_accs3, "b:", label = "Model 3 test acc.")
plt.legend(loc = "best")
plt.ylim([0.9, 1])
plt.show()

# %% [markdown]
# ### What's next?
#
# In this notebook, we were able to perform image recognition using Deep Neural Networks and obtained a rather good test accuracy of 96% after training. While this appears as not too bad, this mainly has to do with MNIST being a nice dataset. In  practice, when it comes to processing images passed as inputs, the fully connected/Linear layers are not really the best choice, and they might rapidly struggle once the images become more sophisticated (higher resolution than 28x28, no longer greyscale but RGB, etc.).
#
# Next week, we will discuss the convolution operation, which is a different operation than the $ Wx + b $ one, which can be used as a layer in Neural Networks, and see why it is far superior when it comes to processing images.
